# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, r2_score, root_mean_squared_error, mean_absolute_error, balanced_accuracy_score
from sklearn.utils.class_weight import compute_sample_weight
from utils import load_plastchem, calculate_mfps
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import EditedNearestNeighbours
from sklearn.decomposition import PCA
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import StratifiedKFold, HalvingGridSearchCV, GridSearchCV
from xgboost import XGBClassifier
import pandas as pd

# %%
# Data preparation
plast_chem, pcc = load_plastchem(Path.cwd() / "data" / "plastchem_db_v1.0.tsv")

hazard_cols = [
        'Hazard_information_Carcinogenic', 'Hazard_information_Mutagenic', 'Hazard_information_Reproduction', 'Hazard_information_CMR', 'Hazard_information_STOT',
        'Hazard_information_EDC', 'Hazard_information_Aquatic_toxicity', 'Hazard_information_PBT', 'Hazard_information_vPvB', 'Hazard_information_PMT', 'Hazard_information_vPvM'
    ]

# exclude NAs
plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
plast_chem_hazard = plast_chem_hazard.where(plast_chem_hazard['Hazard_information_Toxicity_score'] != 0.25)

# include NAs → test for sparsity algo
#plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
#plast_chem_hazard = plast_chem.where(plast_chem['Hazard_information_Toxicity_score'] != 0.25)

print(plast_chem_hazard['Hazard_information_Hazard_score'].value_counts())

# fingerprints
fps = calculate_mfps(plast_chem_hazard, 'Properties_isomeric_smiles')

mask = [fp is not None for fp in fps]
plast_chem_hazard = plast_chem_hazard[mask].copy()
fps = [fp for fp in fps if fp is not None]

X = np.vstack(fps)
# Out:
# Hazard_information_Hazard_score
# 2.0    3049
# 0.5    1188
# 1.0    1041
# 0.0     161
# Name: count, dtype: int64
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors
# [17:44:48] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# ## binary
# - focus on binary, multiclass as extension

# %%
# less hazardous and hazardous 1 and 2 get same category
y = plast_chem_hazard['Hazard_information_Hazard_score'].replace(0.5,1).replace(2,1).replace(3,1)
X = X.copy()
print(y.value_counts(normalize=True))
# Out:
# Hazard_information_Hazard_score
# 1.0    0.967144
# 0.0    0.032856
# Name: proportion, dtype: float64

# %%
# splitting
X_exploration, X_split, y_exploration, y_split = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_split, y_split, test_size=0.5, stratify=y_split, random_state=42)

# %% [markdown]
# ### Training

# %%
pipeline = Pipeline([
    ("pca", PCA(random_state=42)),
    ("enn", EditedNearestNeighbours()),
    ("smote", SMOTE(random_state=42)),
    ("clf", XGBClassifier(tree_method="hist", random_state=42, n_jobs=-1, max_delta_step=3)),
])
param_grid = {
    "pca__n_components": [10, 20, 25, 50],
    "clf__max_depth": [9, 11, 13, 15, 20],
    "clf__learning_rate": [.005, .01, .05, .1],
    "clf__n_estimators": [25, 50, 100, 150]
}
# set n_jobs to 1 here, let xgboost handle parallelization
search = GridSearchCV(
    pipeline,
    param_grid,
    cv=StratifiedKFold(5, shuffle=True, random_state=42),
    scoring="balanced_accuracy",
    verbose=10,
    n_jobs=1
)

# %%
# %%time
search.fit(X_exploration, y_exploration)
# Out:
# Fitting 5 folds for each of 320 candidates, totalling 1600 fits
# [CV 1/5; 1/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10
# [CV 1/5; 1/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10;, score=0.589 total time=  14.9s
# [CV 2/5; 1/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10
# [CV 2/5; 1/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10;, score=0.615 total time=  14.8s
# [CV 3/5; 1/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10
# [CV 3/5; 1/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10;, score=0.622 total time=  14.9s
# [CV 4/5; 1/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10
# [CV 4/5; 1/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10;, score=0.556 total time=  14.9s
# [CV 5/5; 1/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10
# [CV 5/5; 1/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=10;, score=0.566 total time=  15.1s
# [CV 1/5; 2/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20
# [CV 1/5; 2/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20;, score=0.633 total time=  15.2s
# [CV 2/5; 2/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20
# [CV 2/5; 2/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20;, score=0.595 total time=  15.2s
# [CV 3/5; 2/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20
# [CV 3/5; 2/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20;, score=0.664 total time=   2.1s
# [CV 4/5; 2/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20
# [CV 4/5; 2/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20;, score=0.652 total time=   0.4s
# [CV 5/5; 2/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20
# [CV 5/5; 2/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=20;, score=0.510 total time=   0.5s
# [CV 1/5; 3/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25
# [CV 1/5; 3/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25;, score=0.632 total time=   0.4s
# [CV 2/5; 3/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25
# [CV 2/5; 3/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25;, score=0.543 total time=   0.4s
# [CV 3/5; 3/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25
# [CV 3/5; 3/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25;, score=0.709 total time=   0.4s
# [CV 4/5; 3/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25
# [CV 4/5; 3/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25;, score=0.579 total time=   0.4s
# [CV 5/5; 3/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25
# [CV 5/5; 3/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=25;, score=0.564 total time=   0.4s
# [CV 1/5; 4/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50
# [CV 1/5; 4/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50;, score=0.701 total time=   0.4s
# [CV 2/5; 4/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50
# [CV 2/5; 4/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50;, score=0.572 total time=   0.4s
# [CV 3/5; 4/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50
# [CV 3/5; 4/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50;, score=0.655 total time=   0.5s
# [CV 4/5; 4/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50
# [CV 4/5; 4/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50;, score=0.616 total time=   0.5s
# [CV 5/5; 4/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50
# [CV 5/5; 4/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=25, pca__n_components=50;, score=0.587 total time=   0.5s
# [CV 1/5; 5/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10
# [CV 1/5; 5/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10;, score=0.623 total time=   0.3s
# [CV 2/5; 5/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10
# [CV 2/5; 5/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10;, score=0.595 total time=   0.4s
# [CV 3/5; 5/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10
# [CV 3/5; 5/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10;, score=0.649 total time=   0.3s
# [CV 4/5; 5/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10
# [CV 4/5; 5/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10;, score=0.562 total time=   0.6s
# [CV 5/5; 5/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10
# [CV 5/5; 5/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=10;, score=0.611 total time=   0.4s
# [CV 1/5; 6/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20
# [CV 1/5; 6/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20;, score=0.601 total time=   0.4s
# [CV 2/5; 6/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20
# [CV 2/5; 6/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20;, score=0.532 total time=   0.4s
# [CV 3/5; 6/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20
# [CV 3/5; 6/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20;, score=0.668 total time=   0.5s
# [CV 4/5; 6/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20
# [CV 4/5; 6/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20;, score=0.630 total time=   0.5s
# [CV 5/5; 6/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20
# [CV 5/5; 6/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=20;, score=0.532 total time=   0.5s
# [CV 1/5; 7/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25
# [CV 1/5; 7/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25;, score=0.598 total time=   0.4s
# [CV 2/5; 7/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25
# [CV 2/5; 7/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25;, score=0.539 total time=   0.5s
# [CV 3/5; 7/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25
# [CV 3/5; 7/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25;, score=0.713 total time=   0.5s
# [CV 4/5; 7/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25
# [CV 4/5; 7/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25;, score=0.583 total time=   0.5s
# [CV 5/5; 7/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25
# [CV 5/5; 7/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=25;, score=0.576 total time=   0.4s
# [CV 1/5; 8/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50
# [CV 1/5; 8/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50;, score=0.645 total time=   0.5s
# [CV 2/5; 8/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50
# [CV 2/5; 8/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50;, score=0.577 total time=   0.5s
# [CV 3/5; 8/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50
# [CV 3/5; 8/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50;, score=0.684 total time=   0.6s
# [CV 4/5; 8/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50
# [CV 4/5; 8/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50;, score=0.629 total time=   0.5s
# [CV 5/5; 8/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50
# [CV 5/5; 8/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=50, pca__n_components=50;, score=0.585 total time=   0.5s
# [CV 1/5; 9/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10
# [CV 1/5; 9/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10;, score=0.650 total time=   0.5s
# [CV 2/5; 9/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10
# [CV 2/5; 9/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10;, score=0.591 total time=   0.5s
# [CV 3/5; 9/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10
# [CV 3/5; 9/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10;, score=0.655 total time=   0.4s
# [CV 4/5; 9/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10
# [CV 4/5; 9/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10;, score=0.612 total time=   0.5s
# [CV 5/5; 9/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10
# [CV 5/5; 9/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=10;, score=0.576 total time=   0.4s
# [CV 1/5; 10/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20
# [CV 1/5; 10/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20;, score=0.588 total time=   0.5s
# [CV 2/5; 10/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20
# [CV 2/5; 10/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20;, score=0.602 total time=   0.6s
# [CV 3/5; 10/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20
# [CV 3/5; 10/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20;, score=0.668 total time=   0.5s
# [CV 4/5; 10/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20
# [CV 4/5; 10/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20;, score=0.638 total time=   0.5s
# [CV 5/5; 10/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20
# [CV 5/5; 10/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=20;, score=0.542 total time=   0.5s
# [CV 1/5; 11/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25
# [CV 1/5; 11/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25;, score=0.633 total time=   0.5s
# [CV 2/5; 11/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25
# [CV 2/5; 11/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25;, score=0.548 total time=   0.5s
# [CV 3/5; 11/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25
# [CV 3/5; 11/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25;, score=0.696 total time=   0.6s
# [CV 4/5; 11/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25
# [CV 4/5; 11/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25;, score=0.585 total time=   0.6s
# [CV 5/5; 11/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25
# [CV 5/5; 11/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=25;, score=0.536 total time=   0.5s
# [CV 1/5; 12/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50
# [CV 1/5; 12/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50;, score=0.678 total time=   0.6s
# [CV 2/5; 12/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50
# [CV 2/5; 12/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50;, score=0.579 total time=   0.7s
# [CV 3/5; 12/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50
# [CV 3/5; 12/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50;, score=0.712 total time=   0.7s
# [CV 4/5; 12/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50
# [CV 4/5; 12/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50;, score=0.633 total time=   0.8s
# [CV 5/5; 12/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50
# [CV 5/5; 12/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=100, pca__n_components=50;, score=0.579 total time=   0.7s
# [CV 1/5; 13/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10
# [CV 1/5; 13/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10;, score=0.654 total time=   0.5s
# [CV 2/5; 13/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10
# [CV 2/5; 13/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10;, score=0.571 total time=   0.5s
# [CV 3/5; 13/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10
# [CV 3/5; 13/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10;, score=0.649 total time=   0.5s
# [CV 4/5; 13/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10
# [CV 4/5; 13/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10;, score=0.611 total time=   0.5s
# [CV 5/5; 13/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10
# [CV 5/5; 13/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=10;, score=0.555 total time=   0.5s
# [CV 1/5; 14/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20
# [CV 1/5; 14/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20;, score=0.570 total time=   0.6s
# [CV 2/5; 14/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20
# [CV 2/5; 14/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20;, score=0.614 total time=   0.6s
# [CV 3/5; 14/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20
# [CV 3/5; 14/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20;, score=0.694 total time=   0.6s
# [CV 4/5; 14/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20
# [CV 4/5; 14/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20;, score=0.668 total time=   0.6s
# [CV 5/5; 14/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20
# [CV 5/5; 14/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=20;, score=0.543 total time=   0.6s
# [CV 1/5; 15/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25
# [CV 1/5; 15/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25;, score=0.631 total time=   0.6s
# [CV 2/5; 15/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25
# [CV 2/5; 15/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25;, score=0.563 total time=   0.6s
# [CV 3/5; 15/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25
# [CV 3/5; 15/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25;, score=0.674 total time=   0.7s
# [CV 4/5; 15/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25
# [CV 4/5; 15/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25;, score=0.599 total time=   0.7s
# [CV 5/5; 15/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25
# [CV 5/5; 15/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=25;, score=0.573 total time=   0.7s
# [CV 1/5; 16/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50
# [CV 1/5; 16/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50;, score=0.687 total time=   0.8s
# [CV 2/5; 16/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50
# [CV 2/5; 16/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50;, score=0.560 total time=   0.8s
# [CV 3/5; 16/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50
# [CV 3/5; 16/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50;, score=0.712 total time=   0.8s
# [CV 4/5; 16/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50
# [CV 4/5; 16/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50;, score=0.662 total time=   0.9s
# [CV 5/5; 16/320] START clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50
# [CV 5/5; 16/320] END clf__learning_rate=0.005, clf__max_depth=9, clf__n_estimators=150, pca__n_components=50;, score=0.587 total time=   0.8s
# [CV 1/5; 17/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10
# [CV 1/5; 17/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10;, score=0.593 total time=   0.4s
# [CV 2/5; 17/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10
# [CV 2/5; 17/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10;, score=0.618 total time=   0.3s
# [CV 3/5; 17/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10
# [CV 3/5; 17/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10;, score=0.645 total time=   0.4s
# [CV 4/5; 17/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10
# [CV 4/5; 17/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10;, score=0.591 total time=   0.3s
# [CV 5/5; 17/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10
# [CV 5/5; 17/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=10;, score=0.581 total time=   0.4s
# [CV 1/5; 18/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20
# [CV 1/5; 18/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20;, score=0.657 total time=   0.4s
# [CV 2/5; 18/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20
# [CV 2/5; 18/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20;, score=0.547 total time=   0.4s
# [CV 3/5; 18/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20
# [CV 3/5; 18/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20;, score=0.679 total time=   0.4s
# [CV 4/5; 18/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20
# [CV 4/5; 18/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20;, score=0.658 total time=   0.4s
# [CV 5/5; 18/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20
# [CV 5/5; 18/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=20;, score=0.519 total time=   0.4s
# [CV 1/5; 19/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25
# [CV 1/5; 19/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25;, score=0.570 total time=   0.4s
# [CV 2/5; 19/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25
# [CV 2/5; 19/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25;, score=0.540 total time=   0.4s
# [CV 3/5; 19/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25
# [CV 3/5; 19/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25;, score=0.715 total time=   0.4s
# [CV 4/5; 19/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25
# [CV 4/5; 19/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25;, score=0.577 total time=   0.4s
# [CV 5/5; 19/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25
# [CV 5/5; 19/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=25;, score=0.563 total time=   0.4s
# [CV 1/5; 20/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50
# [CV 1/5; 20/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50;, score=0.604 total time=   0.5s
# [CV 2/5; 20/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50
# [CV 2/5; 20/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50;, score=0.561 total time=   0.5s
# [CV 3/5; 20/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50
# [CV 3/5; 20/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50;, score=0.612 total time=   0.5s
# [CV 4/5; 20/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50
# [CV 4/5; 20/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50;, score=0.589 total time=   0.5s
# [CV 5/5; 20/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50
# [CV 5/5; 20/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=25, pca__n_components=50;, score=0.581 total time=   0.6s
# [CV 1/5; 21/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10
# [CV 1/5; 21/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10;, score=0.603 total time=   0.3s
# [CV 2/5; 21/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10
# [CV 2/5; 21/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10;, score=0.638 total time=   0.4s
# [CV 3/5; 21/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10
# [CV 3/5; 21/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10;, score=0.650 total time=   0.4s
# [CV 4/5; 21/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10
# [CV 4/5; 21/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10;, score=0.568 total time=   0.4s
# [CV 5/5; 21/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10
# [CV 5/5; 21/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=10;, score=0.548 total time=   0.5s
# [CV 1/5; 22/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20
# [CV 1/5; 22/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20;, score=0.580 total time=   0.4s
# [CV 2/5; 22/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20
# [CV 2/5; 22/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20;, score=0.546 total time=   0.4s
# [CV 3/5; 22/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20
# [CV 3/5; 22/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20;, score=0.666 total time=   0.5s
# [CV 4/5; 22/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20
# [CV 4/5; 22/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20;, score=0.641 total time=   0.6s
# [CV 5/5; 22/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20
# [CV 5/5; 22/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=20;, score=0.524 total time=   0.5s
# [CV 1/5; 23/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25
# [CV 1/5; 23/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25;, score=0.582 total time=   0.5s
# [CV 2/5; 23/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25
# [CV 2/5; 23/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25;, score=0.521 total time=   0.5s
# [CV 3/5; 23/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25
# [CV 3/5; 23/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25;, score=0.658 total time=   0.5s
# [CV 4/5; 23/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25
# [CV 4/5; 23/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25;, score=0.576 total time=   0.5s
# [CV 5/5; 23/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25
# [CV 5/5; 23/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=25;, score=0.557 total time=   0.5s
# [CV 1/5; 24/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50
# [CV 1/5; 24/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50;, score=0.558 total time=   0.6s
# [CV 2/5; 24/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50
# [CV 2/5; 24/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50;, score=0.542 total time=   0.6s
# [CV 3/5; 24/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50
# [CV 3/5; 24/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50;, score=0.686 total time=   0.6s
# [CV 4/5; 24/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50
# [CV 4/5; 24/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50;, score=0.597 total time=   0.7s
# [CV 5/5; 24/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50
# [CV 5/5; 24/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=50, pca__n_components=50;, score=0.589 total time=   0.6s
# [CV 1/5; 25/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10
# [CV 1/5; 25/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10;, score=0.645 total time=   0.5s
# [CV 2/5; 25/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10
# [CV 2/5; 25/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10;, score=0.610 total time=   0.5s
# [CV 3/5; 25/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10
# [CV 3/5; 25/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10;, score=0.650 total time=   0.5s
# [CV 4/5; 25/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10
# [CV 4/5; 25/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10;, score=0.575 total time=   0.5s
# [CV 5/5; 25/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10
# [CV 5/5; 25/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=10;, score=0.498 total time=   0.5s
# [CV 1/5; 26/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20
# [CV 1/5; 26/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20;, score=0.570 total time=   0.6s
# [CV 2/5; 26/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20
# [CV 2/5; 26/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20;, score=0.576 total time=   0.5s
# [CV 3/5; 26/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20
# [CV 3/5; 26/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20;, score=0.678 total time=   0.6s
# [CV 4/5; 26/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20
# [CV 4/5; 26/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20;, score=0.644 total time=   0.7s
# [CV 5/5; 26/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20
# [CV 5/5; 26/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=20;, score=0.525 total time=   0.5s
# [CV 1/5; 27/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25
# [CV 1/5; 27/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25;, score=0.576 total time=   0.7s
# [CV 2/5; 27/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25
# [CV 2/5; 27/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25;, score=0.529 total time=   0.5s
# [CV 3/5; 27/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25
# [CV 3/5; 27/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25;, score=0.688 total time=   0.6s
# [CV 4/5; 27/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25
# [CV 4/5; 27/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25;, score=0.587 total time=   0.7s
# [CV 5/5; 27/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25
# [CV 5/5; 27/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=25;, score=0.566 total time=   0.6s
# [CV 1/5; 28/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50
# [CV 1/5; 28/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50;, score=0.597 total time=   0.8s
# [CV 2/5; 28/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50
# [CV 2/5; 28/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50;, score=0.559 total time=   0.7s
# [CV 3/5; 28/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50
# [CV 3/5; 28/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50;, score=0.682 total time=   0.8s
# [CV 4/5; 28/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50
# [CV 4/5; 28/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50;, score=0.625 total time=   0.8s
# [CV 5/5; 28/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50
# [CV 5/5; 28/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=100, pca__n_components=50;, score=0.606 total time=   0.8s
# [CV 1/5; 29/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10
# [CV 1/5; 29/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10;, score=0.646 total time=   0.6s
# [CV 2/5; 29/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10
# [CV 2/5; 29/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10;, score=0.592 total time=   0.5s
# [CV 3/5; 29/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10
# [CV 3/5; 29/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10;, score=0.632 total time=   0.5s
# [CV 4/5; 29/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10
# [CV 4/5; 29/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10;, score=0.605 total time=   0.5s
# [CV 5/5; 29/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10
# [CV 5/5; 29/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=10;, score=0.480 total time=   0.5s
# [CV 1/5; 30/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20
# [CV 1/5; 30/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20;, score=0.574 total time=   0.6s
# [CV 2/5; 30/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20
# [CV 2/5; 30/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20;, score=0.586 total time=   0.6s
# [CV 3/5; 30/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20
# [CV 3/5; 30/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20;, score=0.680 total time=   0.7s
# [CV 4/5; 30/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20
# [CV 4/5; 30/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20;, score=0.654 total time=   0.7s
# [CV 5/5; 30/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20
# [CV 5/5; 30/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=20;, score=0.525 total time=   0.7s
# [CV 1/5; 31/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25
# [CV 1/5; 31/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25;, score=0.573 total time=   0.8s
# [CV 2/5; 31/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25
# [CV 2/5; 31/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25;, score=0.544 total time=   0.7s
# [CV 3/5; 31/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25
# [CV 3/5; 31/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25;, score=0.711 total time=   0.7s
# [CV 4/5; 31/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25
# [CV 4/5; 31/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25;, score=0.590 total time=   0.7s
# [CV 5/5; 31/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25
# [CV 5/5; 31/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=25;, score=0.555 total time=   0.7s
# [CV 1/5; 32/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50
# [CV 1/5; 32/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50;, score=0.644 total time=   1.0s
# [CV 2/5; 32/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50
# [CV 2/5; 32/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50;, score=0.563 total time=   0.9s
# [CV 3/5; 32/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50
# [CV 3/5; 32/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50;, score=0.717 total time=   0.9s
# [CV 4/5; 32/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50
# [CV 4/5; 32/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50;, score=0.624 total time=   1.0s
# [CV 5/5; 32/320] START clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50
# [CV 5/5; 32/320] END clf__learning_rate=0.005, clf__max_depth=11, clf__n_estimators=150, pca__n_components=50;, score=0.595 total time=   1.0s
# [CV 1/5; 33/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10
# [CV 1/5; 33/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10;, score=0.585 total time=   0.3s
# [CV 2/5; 33/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10
# [CV 2/5; 33/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10;, score=0.606 total time=   0.3s
# [CV 3/5; 33/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10
# [CV 3/5; 33/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10;, score=0.639 total time=   0.4s
# [CV 4/5; 33/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10
# [CV 4/5; 33/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10;, score=0.586 total time=   0.4s
# [CV 5/5; 33/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10
# [CV 5/5; 33/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=10;, score=0.524 total time=   0.4s
# [CV 1/5; 34/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20
# [CV 1/5; 34/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20;, score=0.664 total time=   0.4s
# [CV 2/5; 34/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20
# [CV 2/5; 34/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20;, score=0.578 total time=   0.4s
# [CV 3/5; 34/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20
# [CV 3/5; 34/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20;, score=0.664 total time=   0.4s
# [CV 4/5; 34/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20
# [CV 4/5; 34/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20;, score=0.672 total time=   0.4s
# [CV 5/5; 34/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20
# [CV 5/5; 34/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=20;, score=0.528 total time=   0.5s
# [CV 1/5; 35/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25
# [CV 1/5; 35/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25;, score=0.606 total time=   0.7s
# [CV 2/5; 35/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25
# [CV 2/5; 35/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25;, score=0.559 total time=   0.4s
# [CV 3/5; 35/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25
# [CV 3/5; 35/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25;, score=0.685 total time=   0.5s
# [CV 4/5; 35/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25
# [CV 4/5; 35/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25;, score=0.556 total time=   0.4s
# [CV 5/5; 35/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25
# [CV 5/5; 35/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=25;, score=0.572 total time=   0.4s
# [CV 1/5; 36/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50
# [CV 1/5; 36/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50;, score=0.616 total time=   0.5s
# [CV 2/5; 36/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50
# [CV 2/5; 36/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50;, score=0.570 total time=   0.6s
# [CV 3/5; 36/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50
# [CV 3/5; 36/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50;, score=0.638 total time=   0.6s
# [CV 4/5; 36/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50
# [CV 4/5; 36/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50;, score=0.594 total time=   0.5s
# [CV 5/5; 36/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50
# [CV 5/5; 36/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=25, pca__n_components=50;, score=0.586 total time=   0.6s
# [CV 1/5; 37/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10
# [CV 1/5; 37/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10;, score=0.630 total time=   0.4s
# [CV 2/5; 37/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10
# [CV 2/5; 37/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10;, score=0.630 total time=   0.4s
# [CV 3/5; 37/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10
# [CV 3/5; 37/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10;, score=0.643 total time=   0.4s
# [CV 4/5; 37/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10
# [CV 4/5; 37/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10;, score=0.589 total time=   0.4s
# [CV 5/5; 37/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10
# [CV 5/5; 37/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=10;, score=0.517 total time=   0.4s
# [CV 1/5; 38/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20
# [CV 1/5; 38/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20;, score=0.586 total time=   0.5s
# [CV 2/5; 38/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20
# [CV 2/5; 38/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20;, score=0.575 total time=   0.5s
# [CV 3/5; 38/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20
# [CV 3/5; 38/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20;, score=0.653 total time=   0.5s
# [CV 4/5; 38/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20
# [CV 4/5; 38/320] END clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20;, score=0.650 total time=   0.5s
# [CV 5/5; 38/320] START clf__learning_rate=0.005, clf__max_depth=13, clf__n_estimators=50, pca__n_components=20
# ...
# [CV 5/5; 309/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=10;, score=0.499 total time=   0.4s
# [CV 1/5; 310/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20
# [CV 1/5; 310/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20;, score=0.576 total time=   0.5s
# [CV 2/5; 310/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20
# [CV 2/5; 310/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20;, score=0.610 total time=   0.5s
# [CV 3/5; 310/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20
# [CV 3/5; 310/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20;, score=0.614 total time=   0.5s
# [CV 4/5; 310/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20
# [CV 4/5; 310/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20;, score=0.665 total time=   0.6s
# [CV 5/5; 310/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20
# [CV 5/5; 310/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=20;, score=0.502 total time=   0.5s
# [CV 1/5; 311/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25
# [CV 1/5; 311/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25;, score=0.581 total time=   0.6s
# [CV 2/5; 311/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25
# [CV 2/5; 311/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25;, score=0.522 total time=   0.5s
# [CV 3/5; 311/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25
# [CV 3/5; 311/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25;, score=0.641 total time=   0.5s
# [CV 4/5; 311/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25
# [CV 4/5; 311/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25;, score=0.623 total time=   0.5s
# [CV 5/5; 311/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25
# [CV 5/5; 311/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=25;, score=0.559 total time=   0.5s
# [CV 1/5; 312/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50
# [CV 1/5; 312/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50;, score=0.564 total time=   0.7s
# [CV 2/5; 312/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50
# [CV 2/5; 312/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50;, score=0.536 total time=   0.6s
# [CV 3/5; 312/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50
# [CV 3/5; 312/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50;, score=0.627 total time=   0.6s
# [CV 4/5; 312/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50
# [CV 4/5; 312/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50;, score=0.601 total time=   0.6s
# [CV 5/5; 312/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50
# [CV 5/5; 312/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=50, pca__n_components=50;, score=0.539 total time=   0.6s
# [CV 1/5; 313/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10
# [CV 1/5; 313/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10;, score=0.631 total time=   0.5s
# [CV 2/5; 313/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10
# [CV 2/5; 313/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10;, score=0.605 total time=   0.4s
# [CV 3/5; 313/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10
# [CV 3/5; 313/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10;, score=0.625 total time=   0.5s
# [CV 4/5; 313/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10
# [CV 4/5; 313/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10;, score=0.558 total time=   0.4s
# [CV 5/5; 313/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10
# [CV 5/5; 313/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=10;, score=0.478 total time=   0.5s
# [CV 1/5; 314/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20
# [CV 1/5; 314/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20;, score=0.580 total time=   0.6s
# [CV 2/5; 314/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20
# [CV 2/5; 314/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20;, score=0.588 total time=   0.6s
# [CV 3/5; 314/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20
# [CV 3/5; 314/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20;, score=0.614 total time=   0.6s
# [CV 4/5; 314/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20
# [CV 4/5; 314/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20;, score=0.646 total time=   0.5s
# [CV 5/5; 314/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20
# [CV 5/5; 314/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=20;, score=0.531 total time=   0.5s
# [CV 1/5; 315/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25
# [CV 1/5; 315/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25;, score=0.584 total time=   0.6s
# [CV 2/5; 315/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25
# [CV 2/5; 315/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25;, score=0.522 total time=   0.7s
# [CV 3/5; 315/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25
# [CV 3/5; 315/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25;, score=0.620 total time=   0.6s
# [CV 4/5; 315/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25
# [CV 4/5; 315/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25;, score=0.601 total time=   0.6s
# [CV 5/5; 315/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25
# [CV 5/5; 315/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=25;, score=0.544 total time=   0.6s
# [CV 1/5; 316/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50
# [CV 1/5; 316/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50;, score=0.586 total time=   0.7s
# [CV 2/5; 316/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50
# [CV 2/5; 316/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50;, score=0.561 total time=   0.7s
# [CV 3/5; 316/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50
# [CV 3/5; 316/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50;, score=0.607 total time=   0.8s
# [CV 4/5; 316/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50
# [CV 4/5; 316/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50;, score=0.602 total time=   0.8s
# [CV 5/5; 316/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50
# [CV 5/5; 316/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=100, pca__n_components=50;, score=0.542 total time=   0.8s
# [CV 1/5; 317/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10
# [CV 1/5; 317/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10;, score=0.592 total time=   0.5s
# [CV 2/5; 317/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10
# [CV 2/5; 317/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10;, score=0.605 total time=   0.5s
# [CV 3/5; 317/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10
# [CV 3/5; 317/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10;, score=0.627 total time=   0.5s
# [CV 4/5; 317/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10
# [CV 4/5; 317/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10;, score=0.559 total time=   0.5s
# [CV 5/5; 317/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10
# [CV 5/5; 317/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=10;, score=0.477 total time=   0.5s
# [CV 1/5; 318/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20
# [CV 1/5; 318/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20;, score=0.579 total time=   0.6s
# [CV 2/5; 318/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20
# [CV 2/5; 318/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20;, score=0.589 total time=   0.6s
# [CV 3/5; 318/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20
# [CV 3/5; 318/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20;, score=0.617 total time=   0.6s
# [CV 4/5; 318/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20
# [CV 4/5; 318/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20;, score=0.647 total time=   0.6s
# [CV 5/5; 318/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20
# [CV 5/5; 318/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=20;, score=0.532 total time=   0.6s
# [CV 1/5; 319/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25
# [CV 1/5; 319/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25;, score=0.583 total time=   0.7s
# [CV 2/5; 319/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25
# [CV 2/5; 319/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25;, score=0.522 total time=   0.6s
# [CV 3/5; 319/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25
# [CV 3/5; 319/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25;, score=0.619 total time=   0.7s
# [CV 4/5; 319/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25
# [CV 4/5; 319/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25;, score=0.605 total time=   0.6s
# [CV 5/5; 319/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25
# [CV 5/5; 319/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=25;, score=0.542 total time=   0.6s
# [CV 1/5; 320/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50
# [CV 1/5; 320/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50;, score=0.589 total time=   0.8s
# [CV 2/5; 320/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50
# [CV 2/5; 320/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50;, score=0.562 total time=   0.8s
# [CV 3/5; 320/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50
# [CV 3/5; 320/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50;, score=0.629 total time=   0.8s
# [CV 4/5; 320/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50
# [CV 4/5; 320/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50;, score=0.606 total time=   0.8s
# [CV 5/5; 320/320] START clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50
# [CV 5/5; 320/320] END clf__learning_rate=0.1, clf__max_depth=20, clf__n_estimators=150, pca__n_components=50;, score=0.544 total time=   0.8s
# CPU times: user 8h 6min 49s, sys: 1min 9s, total: 8h 7min 59s
# Wall time: 17min
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('pca', PCA(random_state=42)),
#                                        ('enn', EditedNearestNeighbours()),
#                                        ('smote', SMOTE(random_state=42)),
#                                        ('clf',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopp...
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None, ...))]),
#              n_jobs=1,
#              param_grid={'clf__learning_rate': [0.005, 0.01, 0.05, 0.1],
#                          'clf__max_depth': [9, 11, 13, 15, 20],
#                          'clf__n_estimators': [25, 50, 100, 150],
#                          'pca__n_components': [10, 20, 25, 50]},
#              scoring='balanced_accuracy', verbose=10)

# %%
print("Best parameter (CV score=%0.3f):" % search.best_score_)
print(search.best_params_)
# Out:
# Best parameter (CV score=0.642):
# {'clf__learning_rate': 0.005, 'clf__max_depth': 9, 'clf__n_estimators': 150, 'pca__n_components': 50}

# %% [markdown]
# ## Testing

# %%
# make predictions
best_model = search.best_estimator_
preds = best_model.predict(X_test)
probs = best_model.predict_proba(X_test)
print(balanced_accuracy_score(y_test, preds))
print(classification_report(y_test, preds))
print(roc_auc_score(y_test, probs[:, 1]))
# Out:
# 0.6064239288193349
#               precision    recall  f1-score   support
#
#          0.0       0.08      0.35      0.13        23
#          1.0       0.98      0.87      0.92       689
#
#     accuracy                           0.85       712
#    macro avg       0.53      0.61      0.52       712
# weighted avg       0.95      0.85      0.89       712
#
# 0.6646683914936581

# %%
cm = confusion_matrix(y_test, preds)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %%
i = search.best_index_
print(search.cv_results_['std_test_score'][i], search.cv_results_['mean_test_score'][i])
# Out:
# 0.0585092923424936 0.6415948222840564

# %% [markdown]
# ### Baseline (Dummy Classifier)

# %%
dummy = DummyClassifier(strategy='stratified', random_state=42)
dummy.fit(X_exploration, y_exploration)
# Out:
# DummyClassifier(random_state=42, strategy='stratified')

# %%
# make predictions
dummy_preds = dummy.predict(X_test)
dummy_probs = dummy.predict_proba(X_test)
print(balanced_accuracy_score(y_test, dummy_preds))
print(classification_report(y_test, dummy_preds))
print(roc_auc_score(y_test, dummy_probs[:, 1]))
# Out:
# 0.4818577648766328
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00        23
#          1.0       0.97      0.96      0.97       689
#
#     accuracy                           0.93       712
#    macro avg       0.48      0.48      0.48       712
# weighted avg       0.94      0.93      0.93       712
#
# 0.4818577648766328

# %%
cm = confusion_matrix(y_test, dummy_preds)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# mainly guesses toxic
