# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.dummy import DummyRegressor
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.utils.class_weight import compute_sample_weight
from utils import load_plastchem, calculate_mfps
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# %%
# Data preparation
plast_chem, pcc = load_plastchem(Path.cwd() / "data" / "plastchem_db_v1.0.tsv")

hazard_cols = [
        'Hazard_information_Carcinogenic', 'Hazard_information_Mutagenic', 'Hazard_information_Reproduction', 'Hazard_information_CMR', 'Hazard_information_STOT',
        'Hazard_information_EDC', 'Hazard_information_Aquatic_toxicity', 'Hazard_information_PBT', 'Hazard_information_vPvB', 'Hazard_information_PMT', 'Hazard_information_vPvM'
    ]

# exclude NAs
plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
plast_chem_hazard = plast_chem_hazard.where(plast_chem_hazard['Hazard_information_Toxicity_score'] != 0.25)

# include NAs → test for sparsity algo
#plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
#plast_chem_hazard = plast_chem.where(plast_chem['Hazard_information_Toxicity_score'] != 0.25)

print(plast_chem_hazard['Hazard_information_Hazard_score'].value_counts())

# fingerprints
fps = calculate_mfps(plast_chem_hazard, 'Properties_isomeric_smiles')

mask = [fp is not None for fp in fps]
plast_chem_hazard = plast_chem_hazard[mask].copy()
fps = [fp for fp in fps if fp is not None]

X = np.vstack(fps)
# Out:
# Hazard_information_Hazard_score
# 2.0    3049
# 0.5    1188
# 1.0    1041
# 0.0     161
# Name: count, dtype: int64
# [14:13:36] WARNING: not removing hydrogen atom without neighbors
# [14:13:36] WARNING: not removing hydrogen atom without neighbors
# [14:13:36] WARNING: not removing hydrogen atom without neighbors
# [14:13:36] WARNING: not removing hydrogen atom without neighbors
# [14:13:36] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors
# [14:13:37] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# ## multiclass classification
# → balance with class size? undersample neg? \
# → TODO: hyperparameter optimization

# %%
# data prep for multiclass
# 1, 2 hazardous; 0.5 less hazardous; 0.25 under development → exclude; 0 not hazardous
y = plast_chem_hazard['Hazard_information_Hazard_score'].replace(2, 3).replace(1, 2).replace(0.5, 1)

# %%
# splitting
X_train, X_split, y_train, y_split = train_test_split(X, y, test_size=0.3, stratify=y)
X_test, X_val, y_test, y_val = train_test_split(X_split, y_split, test_size=0.5, stratify=y_split)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train
)

bst = XGBClassifier(tree_method="hist",
                    n_estimators=300,
                    max_depth=12,
                    learning_rate=0.05,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    eval_metric='mlogloss',
                    max_delta_step=1,
                    booster='gbtree'
                    # set to neg_class_size/pos_class_size
                    #scale_pos_weight=0.56
                    )
# fit model
bst.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# make predictions
preds = bst.predict(X_test)
# Out:
# [0]	validation_0-mlogloss:1.07215
# [1]	validation_0-mlogloss:1.06549
# [2]	validation_0-mlogloss:1.05979
# [3]	validation_0-mlogloss:1.05413
# [4]	validation_0-mlogloss:1.04922
# [5]	validation_0-mlogloss:1.04316
# [6]	validation_0-mlogloss:1.03808
# [7]	validation_0-mlogloss:1.03238
# [8]	validation_0-mlogloss:1.02727
# [9]	validation_0-mlogloss:1.02286
# [10]	validation_0-mlogloss:1.01857
# [11]	validation_0-mlogloss:1.01414
# [12]	validation_0-mlogloss:1.01065
# [13]	validation_0-mlogloss:1.00697
# [14]	validation_0-mlogloss:1.00356
# [15]	validation_0-mlogloss:1.00038
# [16]	validation_0-mlogloss:0.99750
# [17]	validation_0-mlogloss:0.99468
# [18]	validation_0-mlogloss:0.99127
# [19]	validation_0-mlogloss:0.98860
# [20]	validation_0-mlogloss:0.98618
# [21]	validation_0-mlogloss:0.98367
# [22]	validation_0-mlogloss:0.98226
# [23]	validation_0-mlogloss:0.97984
# [24]	validation_0-mlogloss:0.97811
# [25]	validation_0-mlogloss:0.97609
# [26]	validation_0-mlogloss:0.97434
# [27]	validation_0-mlogloss:0.97287
# [28]	validation_0-mlogloss:0.97190
# [29]	validation_0-mlogloss:0.97033
# [30]	validation_0-mlogloss:0.96864
# [31]	validation_0-mlogloss:0.96694
# [32]	validation_0-mlogloss:0.96576
# [33]	validation_0-mlogloss:0.96456
# [34]	validation_0-mlogloss:0.96386
# [35]	validation_0-mlogloss:0.96263
# [36]	validation_0-mlogloss:0.96141
# [37]	validation_0-mlogloss:0.96006
# [38]	validation_0-mlogloss:0.95884
# [39]	validation_0-mlogloss:0.95809
# [40]	validation_0-mlogloss:0.95843
# [41]	validation_0-mlogloss:0.95789
# [42]	validation_0-mlogloss:0.95621
# [43]	validation_0-mlogloss:0.95523
# [44]	validation_0-mlogloss:0.95455
# [45]	validation_0-mlogloss:0.95389
# [46]	validation_0-mlogloss:0.95283
# [47]	validation_0-mlogloss:0.95246
# [48]	validation_0-mlogloss:0.95178
# [49]	validation_0-mlogloss:0.95192
# [50]	validation_0-mlogloss:0.95116
# [51]	validation_0-mlogloss:0.95032
# [52]	validation_0-mlogloss:0.94986
# [53]	validation_0-mlogloss:0.94951
# [54]	validation_0-mlogloss:0.94926
# [55]	validation_0-mlogloss:0.94886
# [56]	validation_0-mlogloss:0.94786
# [57]	validation_0-mlogloss:0.94753
# [58]	validation_0-mlogloss:0.94723
# [59]	validation_0-mlogloss:0.94685
# [60]	validation_0-mlogloss:0.94681
# [61]	validation_0-mlogloss:0.94675
# [62]	validation_0-mlogloss:0.94647
# [63]	validation_0-mlogloss:0.94656
# [64]	validation_0-mlogloss:0.94650
# [65]	validation_0-mlogloss:0.94631
# [66]	validation_0-mlogloss:0.94639
# [67]	validation_0-mlogloss:0.94599
# [68]	validation_0-mlogloss:0.94566
# [69]	validation_0-mlogloss:0.94570
# [70]	validation_0-mlogloss:0.94514
# [71]	validation_0-mlogloss:0.94485
# [72]	validation_0-mlogloss:0.94477
# [73]	validation_0-mlogloss:0.94544
# [74]	validation_0-mlogloss:0.94475
# [75]	validation_0-mlogloss:0.94507
# [76]	validation_0-mlogloss:0.94473
# [77]	validation_0-mlogloss:0.94420
# [78]	validation_0-mlogloss:0.94381
# [79]	validation_0-mlogloss:0.94394
# [80]	validation_0-mlogloss:0.94389
# [81]	validation_0-mlogloss:0.94405
# [82]	validation_0-mlogloss:0.94364
# [83]	validation_0-mlogloss:0.94316
# [84]	validation_0-mlogloss:0.94269
# [85]	validation_0-mlogloss:0.94208
# [86]	validation_0-mlogloss:0.94208
# [87]	validation_0-mlogloss:0.94179
# [88]	validation_0-mlogloss:0.94181
# [89]	validation_0-mlogloss:0.94179
# [90]	validation_0-mlogloss:0.94116
# [91]	validation_0-mlogloss:0.94126
# [92]	validation_0-mlogloss:0.94147
# [93]	validation_0-mlogloss:0.94148
# [94]	validation_0-mlogloss:0.94130
# [95]	validation_0-mlogloss:0.94049
# [96]	validation_0-mlogloss:0.94035
# [97]	validation_0-mlogloss:0.93978
# [98]	validation_0-mlogloss:0.93967
# [99]	validation_0-mlogloss:0.94016
# [100]	validation_0-mlogloss:0.94021
# [101]	validation_0-mlogloss:0.93996
# [102]	validation_0-mlogloss:0.94003
# [103]	validation_0-mlogloss:0.94009
# [104]	validation_0-mlogloss:0.93980
# [105]	validation_0-mlogloss:0.93983
# [106]	validation_0-mlogloss:0.93973
# [107]	validation_0-mlogloss:0.93959
# [108]	validation_0-mlogloss:0.93953
# [109]	validation_0-mlogloss:0.93965
# [110]	validation_0-mlogloss:0.94027
# [111]	validation_0-mlogloss:0.94025
# [112]	validation_0-mlogloss:0.94017
# [113]	validation_0-mlogloss:0.93999
# [114]	validation_0-mlogloss:0.94012
# [115]	validation_0-mlogloss:0.93947
# [116]	validation_0-mlogloss:0.93955
# [117]	validation_0-mlogloss:0.93932
# [118]	validation_0-mlogloss:0.93976
# [119]	validation_0-mlogloss:0.93993
# [120]	validation_0-mlogloss:0.94049
# [121]	validation_0-mlogloss:0.94063
# [122]	validation_0-mlogloss:0.94052
# [123]	validation_0-mlogloss:0.94048
# [124]	validation_0-mlogloss:0.94058
# [125]	validation_0-mlogloss:0.94007
# [126]	validation_0-mlogloss:0.94000
# [127]	validation_0-mlogloss:0.94036
# [128]	validation_0-mlogloss:0.94015
# [129]	validation_0-mlogloss:0.94037
# [130]	validation_0-mlogloss:0.94012
# [131]	validation_0-mlogloss:0.93976
# [132]	validation_0-mlogloss:0.94035
# [133]	validation_0-mlogloss:0.94006
# [134]	validation_0-mlogloss:0.94054
# [135]	validation_0-mlogloss:0.94059
# [136]	validation_0-mlogloss:0.94079
# [137]	validation_0-mlogloss:0.94062
# [138]	validation_0-mlogloss:0.94044
# [139]	validation_0-mlogloss:0.94012
# [140]	validation_0-mlogloss:0.93987
# [141]	validation_0-mlogloss:0.93989
# [142]	validation_0-mlogloss:0.93996
# [143]	validation_0-mlogloss:0.94003
# [144]	validation_0-mlogloss:0.94042
# [145]	validation_0-mlogloss:0.94072
# [146]	validation_0-mlogloss:0.94070
# [147]	validation_0-mlogloss:0.94062
# [148]	validation_0-mlogloss:0.94063
# [149]	validation_0-mlogloss:0.94124
# [150]	validation_0-mlogloss:0.94077
# [151]	validation_0-mlogloss:0.94085
# [152]	validation_0-mlogloss:0.94079
# [153]	validation_0-mlogloss:0.94074
# [154]	validation_0-mlogloss:0.94094
# [155]	validation_0-mlogloss:0.94087
# [156]	validation_0-mlogloss:0.94114
# [157]	validation_0-mlogloss:0.94125
# [158]	validation_0-mlogloss:0.94129
# [159]	validation_0-mlogloss:0.94149
# [160]	validation_0-mlogloss:0.94186
# [161]	validation_0-mlogloss:0.94194
# [162]	validation_0-mlogloss:0.94202
# [163]	validation_0-mlogloss:0.94226
# [164]	validation_0-mlogloss:0.94279
# [165]	validation_0-mlogloss:0.94275
# [166]	validation_0-mlogloss:0.94281
# [167]	validation_0-mlogloss:0.94322
# [168]	validation_0-mlogloss:0.94389
# [169]	validation_0-mlogloss:0.94399
# [170]	validation_0-mlogloss:0.94439
# [171]	validation_0-mlogloss:0.94479
# [172]	validation_0-mlogloss:0.94503
# [173]	validation_0-mlogloss:0.94463
# [174]	validation_0-mlogloss:0.94486
# [175]	validation_0-mlogloss:0.94507
# [176]	validation_0-mlogloss:0.94511
# [177]	validation_0-mlogloss:0.94490
# [178]	validation_0-mlogloss:0.94515
# [179]	validation_0-mlogloss:0.94507
# [180]	validation_0-mlogloss:0.94497
# [181]	validation_0-mlogloss:0.94533
# [182]	validation_0-mlogloss:0.94583
# [183]	validation_0-mlogloss:0.94618
# [184]	validation_0-mlogloss:0.94667
# [185]	validation_0-mlogloss:0.94688
# [186]	validation_0-mlogloss:0.94670
# [187]	validation_0-mlogloss:0.94660
# [188]	validation_0-mlogloss:0.94684
# [189]	validation_0-mlogloss:0.94688
# [190]	validation_0-mlogloss:0.94698
# [191]	validation_0-mlogloss:0.94739
# [192]	validation_0-mlogloss:0.94766
# [193]	validation_0-mlogloss:0.94769
# [194]	validation_0-mlogloss:0.94760
# [195]	validation_0-mlogloss:0.94808
# [196]	validation_0-mlogloss:0.94856
# [197]	validation_0-mlogloss:0.94896
# [198]	validation_0-mlogloss:0.94900
# [199]	validation_0-mlogloss:0.94915
# [200]	validation_0-mlogloss:0.94922
# [201]	validation_0-mlogloss:0.94961
# [202]	validation_0-mlogloss:0.94972
# [203]	validation_0-mlogloss:0.94986
# [204]	validation_0-mlogloss:0.95030
# [205]	validation_0-mlogloss:0.95008
# [206]	validation_0-mlogloss:0.95043
# [207]	validation_0-mlogloss:0.95056
# [208]	validation_0-mlogloss:0.95060
# [209]	validation_0-mlogloss:0.95088
# [210]	validation_0-mlogloss:0.95120
# [211]	validation_0-mlogloss:0.95119
# [212]	validation_0-mlogloss:0.95101
# [213]	validation_0-mlogloss:0.95143
# [214]	validation_0-mlogloss:0.95140
# [215]	validation_0-mlogloss:0.95179
# [216]	validation_0-mlogloss:0.95211
# [217]	validation_0-mlogloss:0.95305
# [218]	validation_0-mlogloss:0.95339
# [219]	validation_0-mlogloss:0.95329
# [220]	validation_0-mlogloss:0.95364
# [221]	validation_0-mlogloss:0.95400
# [222]	validation_0-mlogloss:0.95426
# [223]	validation_0-mlogloss:0.95446
# [224]	validation_0-mlogloss:0.95480
# [225]	validation_0-mlogloss:0.95486
# [226]	validation_0-mlogloss:0.95496
# [227]	validation_0-mlogloss:0.95523
# [228]	validation_0-mlogloss:0.95526
# [229]	validation_0-mlogloss:0.95520
# [230]	validation_0-mlogloss:0.95531
# [231]	validation_0-mlogloss:0.95572
# [232]	validation_0-mlogloss:0.95601
# [233]	validation_0-mlogloss:0.95628
# [234]	validation_0-mlogloss:0.95659
# [235]	validation_0-mlogloss:0.95624
# [236]	validation_0-mlogloss:0.95625
# [237]	validation_0-mlogloss:0.95656
# [238]	validation_0-mlogloss:0.95663
# [239]	validation_0-mlogloss:0.95678
# [240]	validation_0-mlogloss:0.95704
# [241]	validation_0-mlogloss:0.95736
# [242]	validation_0-mlogloss:0.95742
# [243]	validation_0-mlogloss:0.95756
# [244]	validation_0-mlogloss:0.95787
# [245]	validation_0-mlogloss:0.95810
# [246]	validation_0-mlogloss:0.95804
# [247]	validation_0-mlogloss:0.95830
# [248]	validation_0-mlogloss:0.95833
# [249]	validation_0-mlogloss:0.95873
# [250]	validation_0-mlogloss:0.95889
# [251]	validation_0-mlogloss:0.95910
# [252]	validation_0-mlogloss:0.95969
# [253]	validation_0-mlogloss:0.95983
# [254]	validation_0-mlogloss:0.96008
# [255]	validation_0-mlogloss:0.96040
# [256]	validation_0-mlogloss:0.96080
# [257]	validation_0-mlogloss:0.96100
# [258]	validation_0-mlogloss:0.96126
# [259]	validation_0-mlogloss:0.96209
# [260]	validation_0-mlogloss:0.96238
# [261]	validation_0-mlogloss:0.96227
# [262]	validation_0-mlogloss:0.96216
# [263]	validation_0-mlogloss:0.96213
# [264]	validation_0-mlogloss:0.96232
# [265]	validation_0-mlogloss:0.96220
# [266]	validation_0-mlogloss:0.96234
# [267]	validation_0-mlogloss:0.96255
# [268]	validation_0-mlogloss:0.96287
# [269]	validation_0-mlogloss:0.96322
# [270]	validation_0-mlogloss:0.96353
# [271]	validation_0-mlogloss:0.96342
# [272]	validation_0-mlogloss:0.96354
# [273]	validation_0-mlogloss:0.96389
# [274]	validation_0-mlogloss:0.96421
# [275]	validation_0-mlogloss:0.96444
# [276]	validation_0-mlogloss:0.96447
# [277]	validation_0-mlogloss:0.96467
# [278]	validation_0-mlogloss:0.96496
# [279]	validation_0-mlogloss:0.96496
# [280]	validation_0-mlogloss:0.96500
# [281]	validation_0-mlogloss:0.96519
# [282]	validation_0-mlogloss:0.96595
# [283]	validation_0-mlogloss:0.96603
# [284]	validation_0-mlogloss:0.96622
# [285]	validation_0-mlogloss:0.96638
# [286]	validation_0-mlogloss:0.96658
# [287]	validation_0-mlogloss:0.96684
# [288]	validation_0-mlogloss:0.96691
# [289]	validation_0-mlogloss:0.96749
# [290]	validation_0-mlogloss:0.96814
# [291]	validation_0-mlogloss:0.96826
# [292]	validation_0-mlogloss:0.96830
# [293]	validation_0-mlogloss:0.96853
# [294]	validation_0-mlogloss:0.96888
# [295]	validation_0-mlogloss:0.96942
# [296]	validation_0-mlogloss:0.96950
# [297]	validation_0-mlogloss:0.96963
# [298]	validation_0-mlogloss:0.96990
# [299]	validation_0-mlogloss:0.97025

# %%
print(y.value_counts(normalize=True))
y_pred_val = bst.predict(X_val)
print(accuracy_score(y_val, y_pred_val))
preds = bst.predict(X_val)
probs = bst.predict_proba(X_test)

print(classification_report(y_val, preds))
print("ROC-AUC:", roc_auc_score(y_test, probs, multi_class='ovo'))
# Out:
# Hazard_information_Hazard_score
# 3.0    0.566133
# 1.0    0.211036
# 2.0    0.189975
# 0.0    0.032856
# Name: proportion, dtype: float64
# 0.6016830294530154
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.04      0.08        23
#          1.0       0.46      0.34      0.39       151
#          2.0       0.42      0.22      0.29       135
#          3.0       0.66      0.86      0.74       404
#
#     accuracy                           0.60       713
#    macro avg       0.63      0.37      0.38       713
# weighted avg       0.58      0.60      0.56       713
#
# ROC-AUC: 0.7048566116778483

# %%
cm = confusion_matrix(y_val, preds)
disp = ConfusionMatrixDisplay(cm)#, display_labels=class_names)
disp.plot()#xticks_rotation='vertical')
plt.show()

# %% [markdown]
# ### with gridsearchcv
# - Zielpipeline: PCA mit GridSearch um Anzahl der Komponenten festzulegen, GridSearch Parameter XGBoost, Prediction

# %%
from sklearn.experimental import enable_halving_search_cv
from sklearn.model_selection import RandomizedSearchCV, HalvingGridSearchCV

# %%
# %%time
param_grid = {
    'max_depth': [9, 11, 13, 15, 20],
    'learning_rate' : [0.1, 0.01, 0.05, 0.025],
    'n_estimators' : [25, 50, 100, 200]
}

model = XGBClassifier(
    tree_method = 'hist',
    nthread=1
)

grid_search = GridSearchCV(estimator=model,
                           param_grid=param_grid,
                           cv=5, 
                           n_jobs=32,
                           verbose=10)

grid_search.fit(X_train, y_train)

# Print best score and parameters
print(f"Best score: {grid_search.best_score_:.3f}")
print(f"Best parameters: {grid_search.best_params_}")

# Access best model
best_model = grid_search.best_estimator_

# # Save best model
# best_model.save_model('best_model.ubj')

# # Load saved model
# loaded_model = XGBClassifier()
# loaded_model.load_model('best_model.ubj')

# Use loaded model for predictions
predictions = best_model.predict(X_test)

# Print accuracy score
accuracy = best_model.score(X_test, y_test)
print(f"Accuracy: {accuracy:.3f}")
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# Best score: 0.603
# Best parameters: {'learning_rate': 0.05, 'max_depth': 15, 'n_estimators': 100}
# Accuracy: 0.612
# CPU times: user 9.14 s, sys: 280 ms, total: 9.42 s
# Wall time: 2min 48s
# [CV 1/5; 2/48] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 1/5; 2/48] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.598 total time=   2.6s
# [CV 5/5; 5/48] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 5/5; 5/48] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.578 total time=   1.8s
# [CV 1/5; 8/48] START learning_rate=0.1, max_depth=11, n_estimators=200..........
# [CV 1/5; 8/48] END learning_rate=0.1, max_depth=11, n_estimators=200;, score=0.595 total time=   7.4s
# [CV 1/5; 13/48] START learning_rate=0.1, max_depth=15, n_estimators=25..........
# [CV 1/5; 13/48] END learning_rate=0.1, max_depth=15, n_estimators=25;, score=0.602 total time=   2.3s
# [CV 1/5; 14/48] START learning_rate=0.1, max_depth=15, n_estimators=50..........
# [CV 1/5; 14/48] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.594 total time=   3.5s
# [CV 4/5; 16/48] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 4/5; 16/48] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.590 total time=   9.1s
# [CV 3/5; 21/48] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 3/5; 21/48] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.565 total time=   2.3s
# [CV 5/5; 23/48] START learning_rate=0.01, max_depth=11, n_estimators=100........
# [CV 5/5; 23/48] END learning_rate=0.01, max_depth=11, n_estimators=100;, score=0.583 total time=   7.3s
# [CV 1/5; 27/48] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 1/5; 27/48] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.594 total time=   8.9s
# [CV 2/5; 30/48] START learning_rate=0.01, max_depth=15, n_estimators=50.........
# [CV 2/5; 30/48] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.565 total time=   5.2s
# [CV 5/5; 32/48] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 5/5; 32/48] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.583 total time=  17.4s
# [CV 5/5; 41/48] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 5/5; 41/48] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.577 total time=   2.5s
# [CV 4/5; 43/48] START learning_rate=0.05, max_depth=13, n_estimators=100........
# [CV 4/5; 43/48] END learning_rate=0.05, max_depth=13, n_estimators=100;, score=0.596 total time=   6.1s
# [CV 2/5; 47/48] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 2/5; 47/48] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.614 total time=   6.0s
# [CV 2/5; 2/80] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 2/5; 2/80] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.600 total time=   2.4s
# [CV 2/5; 5/80] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 2/5; 5/80] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.605 total time=   2.8s
# [CV 3/5; 7/80] START learning_rate=0.1, max_depth=11, n_estimators=100..........
# [CV 3/5; 7/80] END learning_rate=0.1, max_depth=11, n_estimators=100;, score=0.615 total time=   4.4s
# [CV 1/5; 11/80] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 1/5; 11/80] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.597 total time=   5.0s
# [CV 2/5; 14/80] START learning_rate=0.1, max_depth=15, n_estimators=50..........
# [CV 2/5; 14/80] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.603 total time=   3.3s
# [CV 3/5; 16/80] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 3/5; 16/80] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.603 total time=   8.9s
# [CV 3/5; 21/80] START learning_rate=0.01, max_depth=9, n_estimators=25..........
# [CV 3/5; 21/80] END learning_rate=0.01, max_depth=9, n_estimators=25;, score=0.565 total time=   1.8s
# [CV 5/5; 22/80] START learning_rate=0.01, max_depth=9, n_estimators=50..........
# [CV 5/5; 22/80] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.569 total time=   3.3s
# [CV 1/5; 25/80] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 1/5; 25/80] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.565 total time=   2.1s
# [CV 2/5; 25/80] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 2/5; 25/80] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.565 total time=   2.2s
# [CV 2/5; 27/80] START learning_rate=0.01, max_depth=11, n_estimators=100........
# [CV 2/5; 27/80] END learning_rate=0.01, max_depth=11, n_estimators=100;, score=0.588 total time=   7.8s
# [CV 4/5; 30/80] START learning_rate=0.01, max_depth=13, n_estimators=50.........
# [CV 4/5; 30/80] END learning_rate=0.01, max_depth=13, n_estimators=50;, score=0.571 total time=   4.2s
# [CV 4/5; 32/80] START learning_rate=0.01, max_depth=13, n_estimators=200........
# [CV 4/5; 32/80] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.601 total time=  14.8s
# [CV 5/5; 37/80] START learning_rate=0.01, max_depth=20, n_estimators=25.........
# [CV 5/5; 37/80] END learning_rate=0.01, max_depth=20, n_estimators=25;, score=0.566 total time=   3.2s
# [CV 1/5; 40/80] START learning_rate=0.01, max_depth=20, n_estimators=200........
# [CV 1/5; 40/80] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.588 total time=  21.6s
# [CV 2/5; 49/80] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 2/5; 49/80] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.597 total time=   2.3s
# [CV 5/5; 49/80] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 5/5; 49/80] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.577 total time=   2.3s
# [CV 1/5; 52/80] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 1/5; 52/80] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.595 total time=   9.3s
# [CV 2/5; 57/80] START learning_rate=0.05, max_depth=20, n_estimators=25.........
# [CV 2/5; 57/80] END learning_rate=0.05, max_depth=20, n_estimators=25;, score=0.602 total time=   3.7s
# [CV 3/5; 59/80] START learning_rate=0.05, max_depth=20, n_estimators=100........
# [CV 3/5; 59/80] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.614 total time=   7.7s
# [CV 4/5; 63/80] START learning_rate=0.025, max_depth=9, n_estimators=100........
# [CV 4/5; 63/80] END learning_rate=0.025, max_depth=9, n_estimators=100;, score=0.595 total time=   5.3s
# [CV 5/5; 65/80] START learning_rate=0.025, max_depth=11, n_estimators=25........
# [CV 5/5; 65/80] END learning_rate=0.025, max_depth=11, n_estimators=25;, score=0.574 total time=   2.0s
# [CV 3/5; 67/80] START learning_rate=0.025, max_depth=11, n_estimators=100.......
# [CV 3/5; 67/80] END learning_rate=0.025, max_depth=11, n_estimators=100;, score=0.626 total time=   7.4s
# [CV 5/5; 71/80] START learning_rate=0.025, max_depth=13, n_estimators=100.......
# [CV 5/5; 71/80] END learning_rate=0.025, max_depth=13, n_estimators=100;, score=0.580 total time=   8.9s
# [CV 1/5; 76/80] START learning_rate=0.025, max_depth=15, n_estimators=200.......
# [CV 1/5; 76/80] END learning_rate=0.025, max_depth=15, n_estimators=200;, score=0.595 total time=  12.5s
# [CV 5/5; 1/48] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 5/5; 1/48] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.589 total time=   1.6s
# [CV 2/5; 4/48] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 2/5; 4/48] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.592 total time=   8.1s
# [CV 3/5; 11/48] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 3/5; 11/48] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.618 total time=   4.8s
# [CV 1/5; 15/48] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 1/5; 15/48] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.594 total time=   5.1s
# [CV 3/5; 17/48] START learning_rate=0.01, max_depth=9, n_estimators=25..........
# [CV 3/5; 17/48] END learning_rate=0.01, max_depth=9, n_estimators=25;, score=0.565 total time=   1.9s
# [CV 3/5; 19/48] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 3/5; 19/48] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.588 total time=   6.5s
# [CV 1/5; 23/48] START learning_rate=0.01, max_depth=11, n_estimators=100........
# [CV 1/5; 23/48] END learning_rate=0.01, max_depth=11, n_estimators=100;, score=0.592 total time=   7.7s
# [CV 2/5; 26/48] START learning_rate=0.01, max_depth=13, n_estimators=50.........
# [CV 2/5; 26/48] END learning_rate=0.01, max_depth=13, n_estimators=50;, score=0.567 total time=   4.6s
# [CV 4/5; 28/48] START learning_rate=0.01, max_depth=13, n_estimators=200........
# [CV 4/5; 28/48] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.601 total time=  14.6s
# [CV 1/5; 34/48] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 1/5; 34/48] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.595 total time=   2.9s
# [CV 2/5; 36/48] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 2/5; 36/48] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.605 total time=   7.6s
# [CV 5/5; 39/48] START learning_rate=0.05, max_depth=11, n_estimators=100........
# [CV 5/5; 39/48] END learning_rate=0.05, max_depth=11, n_estimators=100;, score=0.581 total time=   5.2s
# [CV 1/5; 44/48] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 1/5; 44/48] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.595 total time=   9.1s
# [CV 5/5; 48/48] START learning_rate=0.05, max_depth=15, n_estimators=200........
# [CV 5/5; 48/48] END learning_rate=0.05, max_depth=15, n_estimators=200;, score=0.580 total time=   8.7s
# [CV 1/5; 4/80] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 1/5; 4/80] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.603 total time=   6.6s
# [CV 2/5; 9/80] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 2/5; 9/80] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.602 total time=   1.9s
# [CV 3/5; 10/80] START learning_rate=0.1, max_depth=13, n_estimators=50..........
# [CV 3/5; 10/80] END learning_rate=0.1, max_depth=13, n_estimators=50;, score=0.620 total time=   3.1s
# [CV 3/5; 12/80] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 3/5; 12/80] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.608 total time=   8.6s
# [CV 1/5; 18/80] START learning_rate=0.1, max_depth=20, n_estimators=50..........
# [CV 1/5; 18/80] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.597 total time=   4.0s
# [CV 2/5; 20/80] START learning_rate=0.1, max_depth=20, n_estimators=200.........
# [CV 2/5; 20/80] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.606 total time=  11.3s
# [CV 2/5; 26/80] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 2/5; 26/80] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.567 total time=   4.1s
# [CV 2/5; 28/80] START learning_rate=0.01, max_depth=11, n_estimators=200........
# [CV 2/5; 28/80] END learning_rate=0.01, max_depth=11, n_estimators=200;, score=0.605 total time=  13.5s
# [CV 4/5; 34/80] START learning_rate=0.01, max_depth=15, n_estimators=50.........
# [CV 4/5; 34/80] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.571 total time=   4.6s
# [CV 2/5; 36/80] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 2/5; 36/80] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.602 total time=  17.5s
# [CV 1/5; 42/80] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 1/5; 42/80] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.595 total time=   3.1s
# [CV 3/5; 44/80] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 3/5; 44/80] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.623 total time=   7.6s
# [CV 2/5; 48/80] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 2/5; 48/80] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.609 total time=   8.7s
# [CV 4/5; 53/80] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 4/5; 53/80] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.605 total time=   2.4s
# [CV 5/5; 54/80] START learning_rate=0.05, max_depth=15, n_estimators=50.........
# [CV 5/5; 54/80] END learning_rate=0.05, max_depth=15, n_estimators=50;, score=0.572 total time=   4.1s
# [CV 5/5; 56/80] START learning_rate=0.05, max_depth=15, n_estimators=200........
# [CV 5/5; 56/80] END learning_rate=0.05, max_depth=15, n_estimators=200;, score=0.580 total time=  10.2s
# [CV 3/5; 62/80] START learning_rate=0.025, max_depth=9, n_estimators=50.........
# [CV 3/5; 62/80] END learning_rate=0.025, max_depth=9, n_estimators=50;, score=0.592 total time=   3.5s
# [CV 5/5; 64/80] START learning_rate=0.025, max_depth=9, n_estimators=200........
# [CV 5/5; 64/80] END learning_rate=0.025, max_depth=9, n_estimators=200;, score=0.589 total time=   9.2s
# [CV 1/5; 70/80] START learning_rate=0.025, max_depth=13, n_estimators=50........
# [CV 1/5; 70/80] END learning_rate=0.025, max_depth=13, n_estimators=50;, score=0.602 total time=   4.4s
# [CV 2/5; 72/80] START learning_rate=0.025, max_depth=13, n_estimators=200.......
# [CV 2/5; 72/80] END learning_rate=0.025, max_depth=13, n_estimators=200;, score=0.608 total time=  11.5s
# [CV 3/5; 77/80] START learning_rate=0.025, max_depth=20, n_estimators=25........
# [CV 3/5; 77/80] END learning_rate=0.025, max_depth=20, n_estimators=25;, score=0.576 total time=   3.3s
# [CV 5/5; 78/80] START learning_rate=0.025, max_depth=20, n_estimators=50........
# [CV 5/5; 78/80] END learning_rate=0.025, max_depth=20, n_estimators=50;, score=0.568 total time=   6.1s
# [CV 4/5; 3/48] START learning_rate=0.1, max_depth=9, n_estimators=100...........
# [CV 4/5; 3/48] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=0.587 total time=   4.0s
# [CV 1/5; 7/48] START learning_rate=0.1, max_depth=11, n_estimators=100..........
# [CV 1/5; 7/48] END learning_rate=0.1, max_depth=11, n_estimators=100;, score=0.597 total time=   4.4s
# [CV 3/5; 9/48] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 3/5; 9/48] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.629 total time=   2.1s
# [CV 4/5; 11/48] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 4/5; 11/48] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.580 total time=   5.9s
# [CV 5/5; 15/48] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 5/5; 15/48] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.575 total time=   5.5s
# [CV 5/5; 19/48] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 5/5; 19/48] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.578 total time=   6.1s
# [CV 5/5; 22/48] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 5/5; 22/48] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.569 total time=   4.0s
# [CV 1/5; 25/48] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 1/5; 25/48] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.565 total time=   2.4s
# [CV 3/5; 25/48] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 3/5; 25/48] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.565 total time=   2.7s
# [CV 2/5; 27/48] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 2/5; 27/48] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.595 total time=   8.9s
# [CV 1/5; 31/48] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 1/5; 31/48] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.594 total time=  10.0s
# [CV 5/5; 34/48] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 5/5; 34/48] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.578 total time=   2.8s
# [CV 1/5; 37/48] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 1/5; 37/48] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.598 total time=   2.1s
# [CV 3/5; 37/48] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 3/5; 37/48] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.595 total time=   2.3s
# [CV 1/5; 39/48] START learning_rate=0.05, max_depth=11, n_estimators=100........
# [CV 1/5; 39/48] END learning_rate=0.05, max_depth=11, n_estimators=100;, score=0.600 total time=   5.3s
# [CV 2/5; 42/48] START learning_rate=0.05, max_depth=13, n_estimators=50.........
# [CV 2/5; 42/48] END learning_rate=0.05, max_depth=13, n_estimators=50;, score=0.600 total time=   3.7s
# [CV 4/5; 44/48] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 4/5; 44/48] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.584 total time=   9.4s
# [CV 4/5; 1/80] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 4/5; 1/80] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.590 total time=   1.6s
# [CV 2/5; 4/80] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 2/5; 4/80] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.592 total time=   6.7s
# [CV 4/5; 9/80] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 4/5; 9/80] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.596 total time=   2.1s
# [CV 4/5; 11/80] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 4/5; 11/80] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.580 total time=   4.9s
# [CV 2/5; 15/80] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 2/5; 15/80] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.594 total time=   5.0s
# [CV 5/5; 17/80] START learning_rate=0.1, max_depth=20, n_estimators=25..........
# [CV 5/5; 17/80] END learning_rate=0.1, max_depth=20, n_estimators=25;, score=0.583 total time=   2.6s
# [CV 3/5; 19/80] START learning_rate=0.1, max_depth=20, n_estimators=100.........
# [CV 3/5; 19/80] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.594 total time=   7.6s
# [CV 1/5; 24/80] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 1/5; 24/80] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.598 total time=  12.1s
# [CV 4/5; 29/80] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 4/5; 29/80] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.568 total time=   2.3s
# [CV 5/5; 31/80] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 5/5; 31/80] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.574 total time=   8.3s
# [CV 2/5; 34/80] START learning_rate=0.01, max_depth=15, n_estimators=50.........
# [CV 2/5; 34/80] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.565 total time=   5.1s
# [CV 3/5; 36/80] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 3/5; 36/80] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.618 total time=  17.8s
# [CV 5/5; 42/80] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 5/5; 42/80] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.578 total time=   3.0s
# [CV 1/5; 45/80] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 1/5; 45/80] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.598 total time=   2.2s
# [CV 4/5; 45/80] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 4/5; 45/80] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.595 total time=   2.0s
# [CV 5/5; 46/80] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 5/5; 46/80] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.583 total time=   3.4s
# [CV 1/5; 49/80] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 1/5; 49/80] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.603 total time=   2.5s
# [CV 4/5; 49/80] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 4/5; 49/80] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.598 total time=   2.3s
# [CV 4/5; 51/80] START learning_rate=0.05, max_depth=13, n_estimators=100........
# [CV 4/5; 51/80] END learning_rate=0.05, max_depth=13, n_estimators=100;, score=0.596 total time=   5.9s
# [CV 4/5; 55/80] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 4/5; 55/80] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.598 total time=   6.9s
# [CV 5/5; 58/80] START learning_rate=0.05, max_depth=20, n_estimators=50.........
# [CV 5/5; 58/80] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.581 total time=   5.1s
# [CV 1/5; 61/80] START learning_rate=0.025, max_depth=9, n_estimators=25.........
# [CV 1/5; 61/80] END learning_rate=0.025, max_depth=9, n_estimators=25;, score=0.570 total time=   1.9s
# [CV 4/5; 61/80] START learning_rate=0.025, max_depth=9, n_estimators=25.........
# [CV 4/5; 61/80] END learning_rate=0.025, max_depth=9, n_estimators=25;, score=0.574 total time=   1.7s
# [CV 2/5; 63/80] START learning_rate=0.025, max_depth=9, n_estimators=100........
# [CV 2/5; 63/80] END learning_rate=0.025, max_depth=9, n_estimators=100;, score=0.606 total time=   5.6s
# [CV 4/5; 65/80] START learning_rate=0.025, max_depth=11, n_estimators=25........
# [CV 4/5; 65/80] END learning_rate=0.025, max_depth=11, n_estimators=25;, score=0.574 total time=   2.1s
# [CV 1/5; 67/80] START learning_rate=0.025, max_depth=11, n_estimators=100.......
# [CV 1/5; 67/80] END learning_rate=0.025, max_depth=11, n_estimators=100;, score=0.595 total time=   6.9s
# [CV 4/5; 71/80] START learning_rate=0.025, max_depth=13, n_estimators=100.......
# [CV 4/5; 71/80] END learning_rate=0.025, max_depth=13, n_estimators=100;, score=0.599 total time=   7.0s
# [CV 4/5; 74/80] START learning_rate=0.025, max_depth=15, n_estimators=50........
# [CV 4/5; 74/80] END learning_rate=0.025, max_depth=15, n_estimators=50;, score=0.607 total time=   4.8s
# [CV 2/5; 76/80] START learning_rate=0.025, max_depth=15, n_estimators=200.......
# [CV 2/5; 76/80] END learning_rate=0.025, max_depth=15, n_estimators=200;, score=0.605 total time=  12.4s
# [CV 2/5; 2/48] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 2/5; 2/48] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.600 total time=   2.4s
# [CV 2/5; 5/48] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 2/5; 5/48] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.605 total time=   1.8s
# [CV 3/5; 7/48] START learning_rate=0.1, max_depth=11, n_estimators=100..........
# [CV 3/5; 7/48] END learning_rate=0.1, max_depth=11, n_estimators=100;, score=0.615 total time=   4.4s
# [CV 2/5; 10/48] START learning_rate=0.1, max_depth=13, n_estimators=50..........
# [CV 2/5; 10/48] END learning_rate=0.1, max_depth=13, n_estimators=50;, score=0.612 total time=   3.1s
# [CV 2/5; 12/48] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 2/5; 12/48] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.592 total time=   8.6s
# [CV 2/5; 18/48] START learning_rate=0.01, max_depth=9, n_estimators=50..........
# [CV 2/5; 18/48] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.568 total time=   3.3s
# [CV 2/5; 20/48] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 2/5; 20/48] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.603 total time=  11.4s
# [CV 5/5; 25/48] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 5/5; 25/48] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.566 total time=   2.2s
# [CV 3/5; 27/48] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 3/5; 27/48] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.588 total time=   8.9s
# [CV 2/5; 31/48] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 2/5; 31/48] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.592 total time=   9.7s
# [CV 2/5; 34/48] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 2/5; 34/48] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.606 total time=   2.9s
# [CV 3/5; 36/48] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 3/5; 36/48] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.623 total time=   7.6s
# [CV 3/5; 40/48] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 3/5; 40/48] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.614 total time=   8.8s
# [CV 1/5; 46/48] START learning_rate=0.05, max_depth=15, n_estimators=50.........
# [CV 1/5; 46/48] END learning_rate=0.05, max_depth=15, n_estimators=50;, score=0.597 total time=   4.4s
# [CV 2/5; 48/48] START learning_rate=0.05, max_depth=15, n_estimators=200........
# [CV 2/5; 48/48] END learning_rate=0.05, max_depth=15, n_estimators=200;, score=0.606 total time=   8.8s
# [CV 3/5; 3/80] START learning_rate=0.1, max_depth=9, n_estimators=100...........
# [CV 3/5; 3/80] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=0.612 total time=   3.7s
# [CV 3/5; 6/80] START learning_rate=0.1, max_depth=11, n_estimators=50...........
# [CV 3/5; 6/80] END learning_rate=0.1, max_depth=11, n_estimators=50;, score=0.608 total time=   2.6s
# [CV 2/5; 8/80] START learning_rate=0.1, max_depth=11, n_estimators=200..........
# [CV 2/5; 8/80] END learning_rate=0.1, max_depth=11, n_estimators=200;, score=0.586 total time=   7.9s
# [CV 1/5; 14/80] START learning_rate=0.1, max_depth=15, n_estimators=50..........
# [CV 1/5; 14/80] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.594 total time=   3.4s
# [CV 2/5; 16/80] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 2/5; 16/80] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.592 total time=   9.3s
# [CV 4/5; 21/80] START learning_rate=0.01, max_depth=9, n_estimators=25..........
# [CV 4/5; 21/80] END learning_rate=0.01, max_depth=9, n_estimators=25;, score=0.568 total time=   1.7s
# [CV 1/5; 23/80] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 1/5; 23/80] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.588 total time=   6.8s
# [CV 5/5; 25/80] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 5/5; 25/80] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.566 total time=   2.1s
# [CV 1/5; 28/80] START learning_rate=0.01, max_depth=11, n_estimators=200........
# [CV 1/5; 28/80] END learning_rate=0.01, max_depth=11, n_estimators=200;, score=0.595 total time=  14.0s
# [CV 3/5; 33/80] START learning_rate=0.01, max_depth=15, n_estimators=25.........
# [CV 3/5; 33/80] END learning_rate=0.01, max_depth=15, n_estimators=25;, score=0.565 total time=   2.9s
# [CV 3/5; 35/80] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 3/5; 35/80] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.592 total time=  10.0s
# [CV 3/5; 39/80] START learning_rate=0.01, max_depth=20, n_estimators=100........
# [CV 3/5; 39/80] END learning_rate=0.01, max_depth=20, n_estimators=100;, score=0.589 total time=  12.3s
# [CV 4/5; 43/80] START learning_rate=0.05, max_depth=9, n_estimators=100.........
# [CV 4/5; 43/80] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=0.595 total time=   4.8s
# [CV 1/5; 46/80] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 1/5; 46/80] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.600 total time=   3.5s
# [CV 3/5; 47/80] START learning_rate=0.05, max_depth=11, n_estimators=100........
# [CV 3/5; 47/80] END learning_rate=0.05, max_depth=11, n_estimators=100;, score=0.617 total time=   5.6s
# [CV 1/5; 51/80] START learning_rate=0.05, max_depth=13, n_estimators=100........
# [CV 1/5; 51/80] END learning_rate=0.05, max_depth=13, n_estimators=100;, score=0.606 total time=   6.0s
# [CV 3/5; 54/80] START learning_rate=0.05, max_depth=15, n_estimators=50.........
# [CV 3/5; 54/80] END learning_rate=0.05, max_depth=15, n_estimators=50;, score=0.626 total time=   4.6s
# [CV 1/5; 57/80] START learning_rate=0.05, max_depth=20, n_estimators=25.........
# [CV 1/5; 57/80] END learning_rate=0.05, max_depth=20, n_estimators=25;, score=0.591 total time=   3.2s
# [CV 2/5; 59/80] START learning_rate=0.05, max_depth=20, n_estimators=100........
# [CV 2/5; 59/80] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.608 total time=   7.7s
# [CV 1/5; 63/80] START learning_rate=0.025, max_depth=9, n_estimators=100........
# [CV 1/5; 63/80] END learning_rate=0.025, max_depth=9, n_estimators=100;, score=0.595 total time=   5.5s
# [CV 3/5; 65/80] START learning_rate=0.025, max_depth=11, n_estimators=25........
# [CV 3/5; 65/80] END learning_rate=0.025, max_depth=11, n_estimators=25;, score=0.570 total time=   2.2s
# [CV 5/5; 66/80] START learning_rate=0.025, max_depth=11, n_estimators=50........
# [CV 5/5; 66/80] END learning_rate=0.025, max_depth=11, n_estimators=50;, score=0.584 total time=   3.8s
# [CV 5/5; 69/80] START learning_rate=0.025, max_depth=13, n_estimators=25........
# [CV 5/5; 69/80] END learning_rate=0.025, max_depth=13, n_estimators=25;, score=0.577 total time=   2.4s
# [CV 1/5; 71/80] START learning_rate=0.025, max_depth=13, n_estimators=100.......
# [CV 1/5; 71/80] END learning_rate=0.025, max_depth=13, n_estimators=100;, score=0.591 total time=   7.7s
# [CV 1/5; 74/80] START learning_rate=0.025, max_depth=15, n_estimators=50........
# [CV 1/5; 74/80] END learning_rate=0.025, max_depth=15, n_estimators=50;, score=0.595 total time=   5.1s
# [CV 4/5; 76/80] START learning_rate=0.025, max_depth=15, n_estimators=200.......
# [CV 4/5; 76/80] END learning_rate=0.025, max_depth=15, n_estimators=200;, score=0.590 total time=  12.4s
# [CV 3/5; 1/48] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 3/5; 1/48] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.609 total time=   1.9s
# [CV 1/5; 5/48] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 1/5; 5/48] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.598 total time=   1.8s
# [CV 2/5; 6/48] START learning_rate=0.1, max_depth=11, n_estimators=50...........
# [CV 2/5; 6/48] END learning_rate=0.1, max_depth=11, n_estimators=50;, score=0.600 total time=   2.7s
# [CV 2/5; 8/48] START learning_rate=0.1, max_depth=11, n_estimators=200..........
# [CV 2/5; 8/48] END learning_rate=0.1, max_depth=11, n_estimators=200;, score=0.586 total time=   7.6s
# [CV 3/5; 13/48] START learning_rate=0.1, max_depth=15, n_estimators=25..........
# [CV 3/5; 13/48] END learning_rate=0.1, max_depth=15, n_estimators=25;, score=0.618 total time=   3.3s
# [CV 1/5; 16/48] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 1/5; 16/48] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.583 total time=  10.3s
# [CV 2/5; 22/48] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 2/5; 22/48] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.567 total time=   4.0s
# [CV 2/5; 24/48] START learning_rate=0.01, max_depth=11, n_estimators=200........
# [CV 2/5; 24/48] END learning_rate=0.01, max_depth=11, n_estimators=200;, score=0.605 total time=  13.2s
# [CV 4/5; 29/48] START learning_rate=0.01, max_depth=15, n_estimators=25.........
# [CV 4/5; 29/48] END learning_rate=0.01, max_depth=15, n_estimators=25;, score=0.568 total time=   2.4s
# [CV 5/5; 31/48] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 5/5; 31/48] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.575 total time=   9.4s
# [CV 5/5; 35/48] START learning_rate=0.05, max_depth=9, n_estimators=100.........
# [CV 5/5; 35/48] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=0.590 total time=   4.4s
# [CV 5/5; 37/48] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 5/5; 37/48] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.581 total time=   2.0s
# [CV 5/5; 38/48] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 5/5; 38/48] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.583 total time=   3.3s
# [CV 2/5; 41/48] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 2/5; 41/48] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.597 total time=   2.3s
# [CV 4/5; 42/48] START learning_rate=0.05, max_depth=13, n_estimators=50.........
# [CV 4/5; 42/48] END learning_rate=0.05, max_depth=13, n_estimators=50;, score=0.599 total time=   3.6s
# [CV 3/5; 44/48] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 3/5; 44/48] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.615 total time=   9.6s
# [CV 1/5; 2/80] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 1/5; 2/80] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.598 total time=   2.6s
# [CV 1/5; 6/80] START learning_rate=0.1, max_depth=11, n_estimators=50...........
# [CV 1/5; 6/80] END learning_rate=0.1, max_depth=11, n_estimators=50;, score=0.602 total time=   3.9s
# [CV 1/5; 9/80] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 1/5; 9/80] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.588 total time=   2.0s
# [CV 1/5; 10/80] START learning_rate=0.1, max_depth=13, n_estimators=50..........
# [CV 1/5; 10/80] END learning_rate=0.1, max_depth=13, n_estimators=50;, score=0.592 total time=   3.3s
# [CV 5/5; 12/80] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 5/5; 12/80] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.578 total time=   8.4s
# [CV 4/5; 17/80] START learning_rate=0.1, max_depth=20, n_estimators=25..........
# [CV 4/5; 17/80] END learning_rate=0.1, max_depth=20, n_estimators=25;, score=0.599 total time=   2.7s
# [CV 4/5; 19/80] START learning_rate=0.1, max_depth=20, n_estimators=100.........
# [CV 4/5; 19/80] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.598 total time=   6.3s
# [CV 4/5; 23/80] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 4/5; 23/80] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.587 total time=   6.2s
# [CV 1/5; 26/80] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 1/5; 26/80] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.571 total time=   4.5s
# [CV 5/5; 28/80] START learning_rate=0.01, max_depth=11, n_estimators=200........
# [CV 5/5; 28/80] END learning_rate=0.01, max_depth=11, n_estimators=200;, score=0.580 total time=  15.8s
# [CV 1/5; 36/80] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 1/5; 36/80] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.602 total time=  17.6s
# [CV 3/5; 41/80] START learning_rate=0.05, max_depth=9, n_estimators=25..........
# [CV 3/5; 41/80] END learning_rate=0.05, max_depth=9, n_estimators=25;, score=0.592 total time=   1.8s
# [CV 2/5; 42/80] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 2/5; 42/80] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.606 total time=   3.0s
# [CV 2/5; 44/80] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 2/5; 44/80] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.605 total time=   7.7s
# [CV 1/5; 48/80] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 1/5; 48/80] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.583 total time=   8.5s
# [CV 1/5; 53/80] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 1/5; 53/80] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.597 total time=   2.6s
# [CV 2/5; 55/80] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 2/5; 55/80] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.614 total time=   6.3s
# [CV 5/5; 57/80] START learning_rate=0.05, max_depth=20, n_estimators=25.........
# [CV 5/5; 57/80] END learning_rate=0.05, max_depth=20, n_estimators=25;, score=0.577 total time=   3.1s
# [CV 5/5; 59/80] START learning_rate=0.05, max_depth=20, n_estimators=100........
# [CV 5/5; 59/80] END learning_rate=0.05, max_depth=20, n_estimators=100;, score=0.584 total time=   7.9s
# [CV 2/5; 64/80] START learning_rate=0.025, max_depth=9, n_estimators=200........
# [CV 2/5; 64/80] END learning_rate=0.025, max_depth=9, n_estimators=200;, score=0.600 total time=   9.0s
# [CV 5/5; 68/80] START learning_rate=0.025, max_depth=11, n_estimators=200.......
# [CV 5/5; 68/80] END learning_rate=0.025, max_depth=11, n_estimators=200;, score=0.578 total time=  10.8s
# [CV 2/5; 74/80] START learning_rate=0.025, max_depth=15, n_estimators=50........
# [CV 2/5; 74/80] END learning_rate=0.025, max_depth=15, n_estimators=50;, score=0.595 total time=   4.9s
# [CV 3/5; 76/80] START learning_rate=0.025, max_depth=15, n_estimators=200.......
# [CV 3/5; 76/80] END learning_rate=0.025, max_depth=15, n_estimators=200;, score=0.617 total time=  12.6s
# [CV 1/5; 1/48] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 1/5; 1/48] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.597 total time=   1.6s
# [CV 3/5; 4/48] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 3/5; 4/48] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.606 total time=   7.4s
# [CV 1/5; 11/48] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 1/5; 11/48] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.597 total time=   4.9s
# [CV 4/5; 13/48] START learning_rate=0.1, max_depth=15, n_estimators=25..........
# [CV 4/5; 13/48] END learning_rate=0.1, max_depth=15, n_estimators=25;, score=0.601 total time=   2.1s
# [CV 3/5; 15/48] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 3/5; 15/48] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.606 total time=   5.4s
# [CV 4/5; 19/48] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 4/5; 19/48] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.587 total time=   6.3s
# [CV 3/5; 22/48] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 3/5; 22/48] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.568 total time=   4.0s
# [CV 5/5; 24/48] START learning_rate=0.01, max_depth=11, n_estimators=200........
# [CV 5/5; 24/48] END learning_rate=0.01, max_depth=11, n_estimators=200;, score=0.580 total time=  13.4s
# [CV 1/5; 30/48] START learning_rate=0.01, max_depth=15, n_estimators=50.........
# [CV 1/5; 30/48] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.567 total time=   5.2s
# [CV 3/5; 32/48] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 3/5; 32/48] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.618 total time=  17.8s
# [CV 1/5; 42/48] START learning_rate=0.05, max_depth=13, n_estimators=50.........
# [CV 1/5; 42/48] END learning_rate=0.05, max_depth=13, n_estimators=50;, score=0.602 total time=   4.0s
# [CV 2/5; 44/48] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 2/5; 44/48] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.605 total time=   9.3s
# [CV 3/5; 1/80] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 3/5; 1/80] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.609 total time=   1.6s
# [CV 3/5; 4/80] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 3/5; 4/80] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.606 total time=   6.8s
# [CV 5/5; 9/80] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 5/5; 9/80] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.580 total time=   2.0s
# [CV 1/5; 12/80] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 1/5; 12/80] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.589 total time=   8.2s
# [CV 1/5; 17/80] START learning_rate=0.1, max_depth=20, n_estimators=25..........
# [CV 1/5; 17/80] END learning_rate=0.1, max_depth=20, n_estimators=25;, score=0.605 total time=   2.6s
# [CV 5/5; 18/80] START learning_rate=0.1, max_depth=20, n_estimators=50..........
# [CV 5/5; 18/80] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.586 total time=   4.0s
# [CV 1/5; 21/80] START learning_rate=0.01, max_depth=9, n_estimators=25..........
# [CV 1/5; 21/80] END learning_rate=0.01, max_depth=9, n_estimators=25;, score=0.565 total time=   1.8s
# [CV 1/5; 22/80] START learning_rate=0.01, max_depth=9, n_estimators=50..........
# [CV 1/5; 22/80] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.564 total time=   3.5s
# [CV 2/5; 24/80] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 2/5; 24/80] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.603 total time=  11.2s
# [CV 2/5; 29/80] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 2/5; 29/80] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.565 total time=   2.5s
# [CV 1/5; 31/80] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 1/5; 31/80] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.594 total time=   8.8s
# [CV 1/5; 34/80] START learning_rate=0.01, max_depth=15, n_estimators=50.........
# [CV 1/5; 34/80] END learning_rate=0.01, max_depth=15, n_estimators=50;, score=0.567 total time=   5.2s
# [CV 4/5; 36/80] START learning_rate=0.01, max_depth=15, n_estimators=200........
# [CV 4/5; 36/80] END learning_rate=0.01, max_depth=15, n_estimators=200;, score=0.602 total time=  16.4s
# [CV 5/5; 41/80] START learning_rate=0.05, max_depth=9, n_estimators=25..........
# [CV 5/5; 41/80] END learning_rate=0.05, max_depth=9, n_estimators=25;, score=0.581 total time=   1.7s
# [CV 1/5; 43/80] START learning_rate=0.05, max_depth=9, n_estimators=100.........
# [CV 1/5; 43/80] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=0.600 total time=   4.6s
# [CV 3/5; 45/80] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 3/5; 45/80] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.595 total time=   2.1s
# [CV 4/5; 46/80] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 4/5; 46/80] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.601 total time=   3.2s
# [CV 4/5; 48/80] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 4/5; 48/80] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.586 total time=   8.4s
# [CV 3/5; 53/80] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 3/5; 53/80] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.603 total time=   2.8s
# [CV 1/5; 56/80] START learning_rate=0.05, max_depth=15, n_estimators=200........
# [CV 1/5; 56/80] END learning_rate=0.05, max_depth=15, n_estimators=200;, score=0.605 total time=  10.4s
# [CV 2/5; 60/80] START learning_rate=0.05, max_depth=20, n_estimators=200........
# [CV 2/5; 60/80] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.592 total time=  12.5s
# [CV 2/5; 67/80] START learning_rate=0.025, max_depth=11, n_estimators=100.......
# [CV 2/5; 67/80] END learning_rate=0.025, max_depth=11, n_estimators=100;, score=0.605 total time=   6.6s
# [CV 2/5; 71/80] START learning_rate=0.025, max_depth=13, n_estimators=100.......
# [CV 2/5; 71/80] END learning_rate=0.025, max_depth=13, n_estimators=100;, score=0.600 total time=   7.1s
# [CV 3/5; 74/80] START learning_rate=0.025, max_depth=15, n_estimators=50........
# [CV 3/5; 74/80] END learning_rate=0.025, max_depth=15, n_estimators=50;, score=0.605 total time=   5.0s
# [CV 5/5; 76/80] START learning_rate=0.025, max_depth=15, n_estimators=200.......
# [CV 5/5; 76/80] END learning_rate=0.025, max_depth=15, n_estimators=200;, score=0.587 total time=  12.9s
# [CV 2/5; 3/48] START learning_rate=0.1, max_depth=9, n_estimators=100...........
# [CV 2/5; 3/48] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=0.609 total time=   3.9s
# [CV 3/5; 6/48] START learning_rate=0.1, max_depth=11, n_estimators=50...........
# [CV 3/5; 6/48] END learning_rate=0.1, max_depth=11, n_estimators=50;, score=0.608 total time=   2.8s
# [CV 4/5; 8/48] START learning_rate=0.1, max_depth=11, n_estimators=200..........
# [CV 4/5; 8/48] END learning_rate=0.1, max_depth=11, n_estimators=200;, score=0.586 total time=   7.8s
# [CV 4/5; 14/48] START learning_rate=0.1, max_depth=15, n_estimators=50..........
# [CV 4/5; 14/48] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.592 total time=   3.1s
# [CV 2/5; 16/48] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 2/5; 16/48] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.592 total time=   9.5s
# [CV 5/5; 21/48] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 5/5; 21/48] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.566 total time=   2.1s
# [CV 4/5; 23/48] START learning_rate=0.01, max_depth=11, n_estimators=100........
# [CV 4/5; 23/48] END learning_rate=0.01, max_depth=11, n_estimators=100;, score=0.602 total time=   8.3s
# [CV 5/5; 27/48] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 5/5; 27/48] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.574 total time=   9.0s
# [CV 4/5; 31/48] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 4/5; 31/48] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.589 total time=   9.4s
# [CV 4/5; 34/48] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 4/5; 34/48] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.595 total time=   2.8s
# [CV 4/5; 36/48] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 4/5; 36/48] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.595 total time=   7.6s
# [CV 5/5; 40/48] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 5/5; 40/48] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.580 total time=   8.5s
# [CV 4/5; 45/48] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 4/5; 45/48] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.605 total time=   2.5s
# [CV 5/5; 47/48] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 5/5; 47/48] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.581 total time=   6.4s
# [CV 1/5; 3/80] START learning_rate=0.1, max_depth=9, n_estimators=100...........
# [CV 1/5; 3/80] END learning_rate=0.1, max_depth=9, n_estimators=100;, score=0.606 total time=   5.7s
# [CV 1/5; 8/80] START learning_rate=0.1, max_depth=11, n_estimators=200..........
# [CV 1/5; 8/80] END learning_rate=0.1, max_depth=11, n_estimators=200;, score=0.595 total time=   7.7s
# [CV 2/5; 13/80] START learning_rate=0.1, max_depth=15, n_estimators=25..........
# [CV 2/5; 13/80] END learning_rate=0.1, max_depth=15, n_estimators=25;, score=0.603 total time=   2.2s
# [CV 3/5; 15/80] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 3/5; 15/80] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.606 total time=   5.2s
# [CV 3/5; 18/80] START learning_rate=0.1, max_depth=20, n_estimators=50..........
# [CV 3/5; 18/80] END learning_rate=0.1, max_depth=20, n_estimators=50;, score=0.606 total time=   4.0s
# [CV 4/5; 20/80] START learning_rate=0.1, max_depth=20, n_estimators=200.........
# [CV 4/5; 20/80] END learning_rate=0.1, max_depth=20, n_estimators=200;, score=0.587 total time=  11.0s
# [CV 4/5; 26/80] START learning_rate=0.01, max_depth=11, n_estimators=50.........
# [CV 4/5; 26/80] END learning_rate=0.01, max_depth=11, n_estimators=50;, score=0.571 total time=   3.8s
# [CV 3/5; 28/80] START learning_rate=0.01, max_depth=11, n_estimators=200........
# ...
# [CV 2/5; 45/80] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.600 total time=   2.0s
# [CV 3/5; 46/80] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 3/5; 46/80] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.624 total time=   3.4s
# [CV 5/5; 48/80] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 5/5; 48/80] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.580 total time=   8.4s
# [CV 5/5; 53/80] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 5/5; 53/80] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.571 total time=   2.5s
# [CV 5/5; 55/80] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 5/5; 55/80] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.581 total time=   6.5s
# [CV 2/5; 58/80] START learning_rate=0.05, max_depth=20, n_estimators=50.........
# [CV 2/5; 58/80] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.602 total time=   5.1s
# [CV 3/5; 60/80] START learning_rate=0.05, max_depth=20, n_estimators=200........
# [CV 3/5; 60/80] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.612 total time=  12.6s
# [CV 5/5; 67/80] START learning_rate=0.025, max_depth=11, n_estimators=100.......
# [CV 5/5; 67/80] END learning_rate=0.025, max_depth=11, n_estimators=100;, score=0.580 total time=   6.5s
# [CV 1/5; 72/80] START learning_rate=0.025, max_depth=13, n_estimators=200.......
# [CV 1/5; 72/80] END learning_rate=0.025, max_depth=13, n_estimators=200;, score=0.600 total time=  11.4s
# [CV 1/5; 77/80] START learning_rate=0.025, max_depth=20, n_estimators=25........
# [CV 1/5; 77/80] END learning_rate=0.025, max_depth=20, n_estimators=25;, score=0.576 total time=   3.2s
# [CV 2/5; 78/80] START learning_rate=0.025, max_depth=20, n_estimators=50........
# [CV 2/5; 78/80] END learning_rate=0.025, max_depth=20, n_estimators=50;, score=0.595 total time=   6.0s
# [CV 3/5; 80/80] START learning_rate=0.025, max_depth=20, n_estimators=200.......
# [CV 3/5; 80/80] END learning_rate=0.025, max_depth=20, n_estimators=200;, score=0.617 total time=  13.5s
# [CV 5/5; 2/48] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 5/5; 2/48] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.590 total time=   2.5s
# [CV 3/5; 5/48] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 3/5; 5/48] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.620 total time=   1.8s
# [CV 5/5; 7/48] START learning_rate=0.1, max_depth=11, n_estimators=100..........
# [CV 5/5; 7/48] END learning_rate=0.1, max_depth=11, n_estimators=100;, score=0.586 total time=   4.3s
# [CV 3/5; 10/48] START learning_rate=0.1, max_depth=13, n_estimators=50..........
# [CV 3/5; 10/48] END learning_rate=0.1, max_depth=13, n_estimators=50;, score=0.620 total time=   3.1s
# [CV 3/5; 12/48] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 3/5; 12/48] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.608 total time=   8.4s
# [CV 5/5; 17/48] START learning_rate=0.01, max_depth=9, n_estimators=25..........
# [CV 5/5; 17/48] END learning_rate=0.01, max_depth=9, n_estimators=25;, score=0.566 total time=   1.8s
# [CV 1/5; 20/48] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 1/5; 20/48] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.598 total time=  11.6s
# [CV 2/5; 25/48] START learning_rate=0.01, max_depth=13, n_estimators=25.........
# [CV 2/5; 25/48] END learning_rate=0.01, max_depth=13, n_estimators=25;, score=0.565 total time=   2.4s
# [CV 3/5; 26/48] START learning_rate=0.01, max_depth=13, n_estimators=50.........
# [CV 3/5; 26/48] END learning_rate=0.01, max_depth=13, n_estimators=50;, score=0.568 total time=   4.6s
# [CV 5/5; 28/48] START learning_rate=0.01, max_depth=13, n_estimators=200........
# [CV 5/5; 28/48] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.578 total time=  15.3s
# [CV 3/5; 34/48] START learning_rate=0.05, max_depth=9, n_estimators=50..........
# [CV 3/5; 34/48] END learning_rate=0.05, max_depth=9, n_estimators=50;, score=0.608 total time=   3.0s
# [CV 5/5; 36/48] START learning_rate=0.05, max_depth=9, n_estimators=200.........
# [CV 5/5; 36/48] END learning_rate=0.05, max_depth=9, n_estimators=200;, score=0.590 total time=   7.5s
# [CV 1/5; 41/48] START learning_rate=0.05, max_depth=13, n_estimators=25.........
# [CV 1/5; 41/48] END learning_rate=0.05, max_depth=13, n_estimators=25;, score=0.603 total time=   2.4s
# [CV 3/5; 42/48] START learning_rate=0.05, max_depth=13, n_estimators=50.........
# [CV 3/5; 42/48] END learning_rate=0.05, max_depth=13, n_estimators=50;, score=0.627 total time=   3.9s
# [CV 5/5; 44/48] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 5/5; 44/48] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.575 total time=   9.2s
# [CV 5/5; 1/80] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 5/5; 1/80] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.589 total time=   1.6s
# [CV 4/5; 4/80] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 4/5; 4/80] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.580 total time=   7.0s
# [CV 4/5; 10/80] START learning_rate=0.1, max_depth=13, n_estimators=50..........
# [CV 4/5; 10/80] END learning_rate=0.1, max_depth=13, n_estimators=50;, score=0.593 total time=   3.0s
# [CV 2/5; 12/80] START learning_rate=0.1, max_depth=13, n_estimators=200.........
# [CV 2/5; 12/80] END learning_rate=0.1, max_depth=13, n_estimators=200;, score=0.592 total time=   8.4s
# [CV 3/5; 17/80] START learning_rate=0.1, max_depth=20, n_estimators=25..........
# [CV 3/5; 17/80] END learning_rate=0.1, max_depth=20, n_estimators=25;, score=0.606 total time=   2.6s
# [CV 2/5; 19/80] START learning_rate=0.1, max_depth=20, n_estimators=100.........
# [CV 2/5; 19/80] END learning_rate=0.1, max_depth=20, n_estimators=100;, score=0.603 total time=   6.2s
# [CV 3/5; 23/80] START learning_rate=0.01, max_depth=9, n_estimators=100.........
# [CV 3/5; 23/80] END learning_rate=0.01, max_depth=9, n_estimators=100;, score=0.588 total time=   6.5s
# [CV 4/5; 25/80] START learning_rate=0.01, max_depth=11, n_estimators=25.........
# [CV 4/5; 25/80] END learning_rate=0.01, max_depth=11, n_estimators=25;, score=0.568 total time=   2.0s
# [CV 4/5; 27/80] START learning_rate=0.01, max_depth=11, n_estimators=100........
# [CV 4/5; 27/80] END learning_rate=0.01, max_depth=11, n_estimators=100;, score=0.602 total time=   7.3s
# [CV 3/5; 31/80] START learning_rate=0.01, max_depth=13, n_estimators=100........
# [CV 3/5; 31/80] END learning_rate=0.01, max_depth=13, n_estimators=100;, score=0.588 total time=   9.0s
# [CV 1/5; 35/80] START learning_rate=0.01, max_depth=15, n_estimators=100........
# [CV 1/5; 35/80] END learning_rate=0.01, max_depth=15, n_estimators=100;, score=0.594 total time=   9.8s
# [CV 2/5; 38/80] START learning_rate=0.01, max_depth=20, n_estimators=50.........
# [CV 2/5; 38/80] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.565 total time=   5.9s
# [CV 3/5; 40/80] START learning_rate=0.01, max_depth=20, n_estimators=200........
# [CV 3/5; 40/80] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.611 total time=  21.8s
# [CV 3/5; 51/80] START learning_rate=0.05, max_depth=13, n_estimators=100........
# [CV 3/5; 51/80] END learning_rate=0.05, max_depth=13, n_estimators=100;, score=0.618 total time=   6.0s
# [CV 3/5; 55/80] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 3/5; 55/80] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.620 total time=   6.6s
# [CV 3/5; 58/80] START learning_rate=0.05, max_depth=20, n_estimators=50.........
# [CV 3/5; 58/80] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.617 total time=   5.2s
# [CV 5/5; 60/80] START learning_rate=0.05, max_depth=20, n_estimators=200........
# [CV 5/5; 60/80] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.586 total time=  12.9s
# [CV 1/5; 68/80] START learning_rate=0.025, max_depth=11, n_estimators=200.......
# [CV 1/5; 68/80] END learning_rate=0.025, max_depth=11, n_estimators=200;, score=0.598 total time=  10.2s
# [CV 1/5; 73/80] START learning_rate=0.025, max_depth=15, n_estimators=25........
# [CV 1/5; 73/80] END learning_rate=0.025, max_depth=15, n_estimators=25;, score=0.571 total time=   2.7s
# [CV 5/5; 74/80] START learning_rate=0.025, max_depth=15, n_estimators=50........
# [CV 5/5; 74/80] END learning_rate=0.025, max_depth=15, n_estimators=50;, score=0.574 total time=   4.9s
# [CV 2/5; 77/80] START learning_rate=0.025, max_depth=20, n_estimators=25........
# [CV 2/5; 77/80] END learning_rate=0.025, max_depth=20, n_estimators=25;, score=0.580 total time=   3.3s
# [CV 3/5; 78/80] START learning_rate=0.025, max_depth=20, n_estimators=50........
# [CV 3/5; 78/80] END learning_rate=0.025, max_depth=20, n_estimators=50;, score=0.600 total time=   6.2s
# [CV 5/5; 80/80] START learning_rate=0.025, max_depth=20, n_estimators=200.......
# [CV 5/5; 80/80] END learning_rate=0.025, max_depth=20, n_estimators=200;, score=0.586 total time=  13.2s
# [CV 4/5; 1/48] START learning_rate=0.1, max_depth=9, n_estimators=25............
# [CV 4/5; 1/48] END learning_rate=0.1, max_depth=9, n_estimators=25;, score=0.590 total time=   1.7s
# [CV 4/5; 4/48] START learning_rate=0.1, max_depth=9, n_estimators=200...........
# [CV 4/5; 4/48] END learning_rate=0.1, max_depth=9, n_estimators=200;, score=0.580 total time=   6.7s
# [CV 4/5; 9/48] START learning_rate=0.1, max_depth=13, n_estimators=25...........
# [CV 4/5; 9/48] END learning_rate=0.1, max_depth=13, n_estimators=25;, score=0.596 total time=   2.0s
# [CV 5/5; 11/48] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 5/5; 11/48] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.574 total time=   4.8s
# [CV 2/5; 15/48] START learning_rate=0.1, max_depth=15, n_estimators=100.........
# [CV 2/5; 15/48] END learning_rate=0.1, max_depth=15, n_estimators=100;, score=0.594 total time=   5.2s
# [CV 4/5; 18/48] START learning_rate=0.01, max_depth=9, n_estimators=50..........
# [CV 4/5; 18/48] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.571 total time=   3.4s
# [CV 5/5; 20/48] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 5/5; 20/48] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.580 total time=  11.3s
# [CV 1/5; 26/48] START learning_rate=0.01, max_depth=13, n_estimators=50.........
# [CV 1/5; 26/48] END learning_rate=0.01, max_depth=13, n_estimators=50;, score=0.568 total time=   4.5s
# [CV 2/5; 28/48] START learning_rate=0.01, max_depth=13, n_estimators=200........
# [CV 2/5; 28/48] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.602 total time=  15.1s
# [CV 5/5; 33/48] START learning_rate=0.05, max_depth=9, n_estimators=25..........
# [CV 5/5; 33/48] END learning_rate=0.05, max_depth=9, n_estimators=25;, score=0.581 total time=   1.7s
# [CV 4/5; 35/48] START learning_rate=0.05, max_depth=9, n_estimators=100.........
# [CV 4/5; 35/48] END learning_rate=0.05, max_depth=9, n_estimators=100;, score=0.595 total time=   4.4s
# [CV 4/5; 37/48] START learning_rate=0.05, max_depth=11, n_estimators=25.........
# [CV 4/5; 37/48] END learning_rate=0.05, max_depth=11, n_estimators=25;, score=0.595 total time=   2.0s
# [CV 4/5; 38/48] START learning_rate=0.05, max_depth=11, n_estimators=50.........
# [CV 4/5; 38/48] END learning_rate=0.05, max_depth=11, n_estimators=50;, score=0.601 total time=   3.2s
# [CV 4/5; 40/48] START learning_rate=0.05, max_depth=11, n_estimators=200........
# [CV 4/5; 40/48] END learning_rate=0.05, max_depth=11, n_estimators=200;, score=0.586 total time=   8.2s
# [CV 3/5; 45/48] START learning_rate=0.05, max_depth=15, n_estimators=25.........
# [CV 3/5; 45/48] END learning_rate=0.05, max_depth=15, n_estimators=25;, score=0.603 total time=   2.7s
# [CV 4/5; 47/48] START learning_rate=0.05, max_depth=15, n_estimators=100........
# [CV 4/5; 47/48] END learning_rate=0.05, max_depth=15, n_estimators=100;, score=0.598 total time=   5.9s
# [CV 4/5; 2/80] START learning_rate=0.1, max_depth=9, n_estimators=50............
# [CV 4/5; 2/80] END learning_rate=0.1, max_depth=9, n_estimators=50;, score=0.587 total time=   2.4s
# [CV 4/5; 5/80] START learning_rate=0.1, max_depth=11, n_estimators=25...........
# [CV 4/5; 5/80] END learning_rate=0.1, max_depth=11, n_estimators=25;, score=0.601 total time=   2.8s
# [CV 4/5; 7/80] START learning_rate=0.1, max_depth=11, n_estimators=100..........
# [CV 4/5; 7/80] END learning_rate=0.1, max_depth=11, n_estimators=100;, score=0.590 total time=   4.6s
# [CV 3/5; 11/80] START learning_rate=0.1, max_depth=13, n_estimators=100.........
# [CV 3/5; 11/80] END learning_rate=0.1, max_depth=13, n_estimators=100;, score=0.618 total time=   5.0s
# [CV 5/5; 14/80] START learning_rate=0.1, max_depth=15, n_estimators=50..........
# [CV 5/5; 14/80] END learning_rate=0.1, max_depth=15, n_estimators=50;, score=0.572 total time=   3.3s
# [CV 5/5; 16/80] START learning_rate=0.1, max_depth=15, n_estimators=200.........
# [CV 5/5; 16/80] END learning_rate=0.1, max_depth=15, n_estimators=200;, score=0.578 total time=   9.0s
# [CV 2/5; 22/80] START learning_rate=0.01, max_depth=9, n_estimators=50..........
# [CV 2/5; 22/80] END learning_rate=0.01, max_depth=9, n_estimators=50;, score=0.568 total time=   3.4s
# [CV 3/5; 24/80] START learning_rate=0.01, max_depth=9, n_estimators=200.........
# [CV 3/5; 24/80] END learning_rate=0.01, max_depth=9, n_estimators=200;, score=0.606 total time=  12.0s
# [CV 1/5; 30/80] START learning_rate=0.01, max_depth=13, n_estimators=50.........
# [CV 1/5; 30/80] END learning_rate=0.01, max_depth=13, n_estimators=50;, score=0.568 total time=   4.6s
# [CV 3/5; 32/80] START learning_rate=0.01, max_depth=13, n_estimators=200........
# [CV 3/5; 32/80] END learning_rate=0.01, max_depth=13, n_estimators=200;, score=0.620 total time=  16.5s
# [CV 4/5; 38/80] START learning_rate=0.01, max_depth=20, n_estimators=50.........
# [CV 4/5; 38/80] END learning_rate=0.01, max_depth=20, n_estimators=50;, score=0.571 total time=   5.8s
# [CV 4/5; 40/80] START learning_rate=0.01, max_depth=20, n_estimators=200........
# [CV 4/5; 40/80] END learning_rate=0.01, max_depth=20, n_estimators=200;, score=0.598 total time=  20.9s
# [CV 3/5; 50/80] START learning_rate=0.05, max_depth=13, n_estimators=50.........
# [CV 3/5; 50/80] END learning_rate=0.05, max_depth=13, n_estimators=50;, score=0.627 total time=   3.9s
# [CV 4/5; 52/80] START learning_rate=0.05, max_depth=13, n_estimators=200........
# [CV 4/5; 52/80] END learning_rate=0.05, max_depth=13, n_estimators=200;, score=0.584 total time=   9.5s
# [CV 4/5; 58/80] START learning_rate=0.05, max_depth=20, n_estimators=50.........
# [CV 4/5; 58/80] END learning_rate=0.05, max_depth=20, n_estimators=50;, score=0.592 total time=   5.0s
# [CV 4/5; 60/80] START learning_rate=0.05, max_depth=20, n_estimators=200........
# [CV 4/5; 60/80] END learning_rate=0.05, max_depth=20, n_estimators=200;, score=0.598 total time=  12.2s
# [CV 4/5; 67/80] START learning_rate=0.025, max_depth=11, n_estimators=100.......
# [CV 4/5; 67/80] END learning_rate=0.025, max_depth=11, n_estimators=100;, score=0.599 total time=   6.2s
# [CV 3/5; 71/80] START learning_rate=0.025, max_depth=13, n_estimators=100.......
# [CV 3/5; 71/80] END learning_rate=0.025, max_depth=13, n_estimators=100;, score=0.632 total time=   7.5s
# [CV 1/5; 75/80] START learning_rate=0.025, max_depth=15, n_estimators=100.......
# [CV 1/5; 75/80] END learning_rate=0.025, max_depth=15, n_estimators=100;, score=0.589 total time=   8.4s
# [CV 4/5; 78/80] START learning_rate=0.025, max_depth=20, n_estimators=50........
# [CV 4/5; 78/80] END learning_rate=0.025, max_depth=20, n_estimators=50;, score=0.601 total time=   5.8s
# [CV 4/5; 80/80] START learning_rate=0.025, max_depth=20, n_estimators=200.......
# [CV 4/5; 80/80] END learning_rate=0.025, max_depth=20, n_estimators=200;, score=0.598 total time=  13.4s

# %% [markdown]
# ## binary classification

# %%
# less hazardous and hazardous 1 and 2 get same category
y_b = plast_chem_hazard['Hazard_information_Hazard_score'].replace(0.5,1).replace(2,1).replace(3,1)
X_b = X.copy()
print(y_b.value_counts(normalize=True))
# Out:
# Hazard_information_Hazard_score
# 1.0    0.967144
# 0.0    0.032856
# Name: proportion, dtype: float64

# %%
# splitting
X_train_b, X_split_b, y_train_b, y_split_b = train_test_split(X_b, y_b, test_size=0.3, stratify=y_b)
X_test_b, X_val_b, y_test_b, y_val_b = train_test_split(X_split_b, y_split_b, test_size=0.5, stratify=y_split_b)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train_b
)

bst = XGBClassifier(tree_method="hist",
                    n_estimators=300,
                    max_depth=4,
                    learning_rate=0.1,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    #eval_metric='mlogloss',
                    #max_delta_step=1,
                    # set to neg_class_size/pos_class_size
                    scale_pos_weight=0.032856/0.967144
                    )
# fit model
bst.fit(X_train_b, y_train_b, eval_set=[(X_test, y_test)])
# make predictions
preds = bst.predict(X_val_b)
# Out:
# [0]	validation_0-logloss:0.61784
# [1]	validation_0-logloss:0.58603
# [2]	validation_0-logloss:0.56534
# [3]	validation_0-logloss:0.52437
# [4]	validation_0-logloss:0.49655
# [5]	validation_0-logloss:0.46027
# [6]	validation_0-logloss:0.43649
# [7]	validation_0-logloss:0.41208
# [8]	validation_0-logloss:0.39827
# [9]	validation_0-logloss:0.38747
# [10]	validation_0-logloss:0.37911
# [11]	validation_0-logloss:0.36673
# [12]	validation_0-logloss:0.36058
# [13]	validation_0-logloss:0.34263
# [14]	validation_0-logloss:0.32622
# [15]	validation_0-logloss:0.31691
# [16]	validation_0-logloss:0.30329
# [17]	validation_0-logloss:0.30258
# [18]	validation_0-logloss:0.31282
# [19]	validation_0-logloss:0.31060
# [20]	validation_0-logloss:0.29371
# [21]	validation_0-logloss:0.26327
# [22]	validation_0-logloss:0.22185
# [23]	validation_0-logloss:0.20682
# [24]	validation_0-logloss:0.20958
# [25]	validation_0-logloss:0.19994
# [26]	validation_0-logloss:0.18493
# [27]	validation_0-logloss:0.16648
# [28]	validation_0-logloss:0.15642
# [29]	validation_0-logloss:0.15154
# [30]	validation_0-logloss:0.15140
# [31]	validation_0-logloss:0.14113
# [32]	validation_0-logloss:0.14309
# [33]	validation_0-logloss:0.12582
# [34]	validation_0-logloss:0.12729
# [35]	validation_0-logloss:0.10989
# [36]	validation_0-logloss:0.11000
# [37]	validation_0-logloss:0.11710
# [38]	validation_0-logloss:0.09535
# [39]	validation_0-logloss:0.07248
# [40]	validation_0-logloss:0.08308
# [41]	validation_0-logloss:0.09524
# [42]	validation_0-logloss:0.08704
# [43]	validation_0-logloss:0.06762
# [44]	validation_0-logloss:0.05487
# [45]	validation_0-logloss:0.02699
# [46]	validation_0-logloss:0.02324
# [47]	validation_0-logloss:0.00976
# [48]	validation_0-logloss:-0.00446
# [49]	validation_0-logloss:0.00193
# [50]	validation_0-logloss:0.00447
# [51]	validation_0-logloss:-0.00156
# [52]	validation_0-logloss:-0.00664
# [53]	validation_0-logloss:-0.00815
# [54]	validation_0-logloss:-0.01953
# [55]	validation_0-logloss:-0.03606
# [56]	validation_0-logloss:-0.05102
# [57]	validation_0-logloss:-0.07881
# [58]	validation_0-logloss:-0.06336
# [59]	validation_0-logloss:-0.06566
# [60]	validation_0-logloss:-0.07094
# [61]	validation_0-logloss:-0.07494
# [62]	validation_0-logloss:-0.09847
# [63]	validation_0-logloss:-0.10896
# [64]	validation_0-logloss:-0.11550
# [65]	validation_0-logloss:-0.12029
# [66]	validation_0-logloss:-0.10697
# [67]	validation_0-logloss:-0.11973
# [68]	validation_0-logloss:-0.12769
# [69]	validation_0-logloss:-0.14906
# [70]	validation_0-logloss:-0.13467
# [71]	validation_0-logloss:-0.13203
# [72]	validation_0-logloss:-0.14648
# [73]	validation_0-logloss:-0.13561
# [74]	validation_0-logloss:-0.15131
# [75]	validation_0-logloss:-0.16538
# [76]	validation_0-logloss:-0.16150
# [77]	validation_0-logloss:-0.16546
# [78]	validation_0-logloss:-0.14843
# [79]	validation_0-logloss:-0.15370
# [80]	validation_0-logloss:-0.17268
# [81]	validation_0-logloss:-0.18750
# [82]	validation_0-logloss:-0.19790
# [83]	validation_0-logloss:-0.19910
# [84]	validation_0-logloss:-0.19053
# [85]	validation_0-logloss:-0.20736
# [86]	validation_0-logloss:-0.22060
# [87]	validation_0-logloss:-0.21864
# [88]	validation_0-logloss:-0.23198
# [89]	validation_0-logloss:-0.21622
# [90]	validation_0-logloss:-0.21007
# [91]	validation_0-logloss:-0.21683
# [92]	validation_0-logloss:-0.21790
# [93]	validation_0-logloss:-0.23755
# [94]	validation_0-logloss:-0.24635
# [95]	validation_0-logloss:-0.25515
# [96]	validation_0-logloss:-0.27077
# [97]	validation_0-logloss:-0.27860
# [98]	validation_0-logloss:-0.28357
# [99]	validation_0-logloss:-0.29024
# [100]	validation_0-logloss:-0.28847
# [101]	validation_0-logloss:-0.28888
# [102]	validation_0-logloss:-0.28801
# [103]	validation_0-logloss:-0.29769
# [104]	validation_0-logloss:-0.31097
# [105]	validation_0-logloss:-0.32218
# [106]	validation_0-logloss:-0.33592
# [107]	validation_0-logloss:-0.34979
# [108]	validation_0-logloss:-0.35124
# [109]	validation_0-logloss:-0.35031
# [110]	validation_0-logloss:-0.36484
# [111]	validation_0-logloss:-0.36883
# [112]	validation_0-logloss:-0.36363
# [113]	validation_0-logloss:-0.36274
# [114]	validation_0-logloss:-0.37360
# [115]	validation_0-logloss:-0.38065
# [116]	validation_0-logloss:-0.37246
# [117]	validation_0-logloss:-0.38079
# [118]	validation_0-logloss:-0.37902
# [119]	validation_0-logloss:-0.36478
# [120]	validation_0-logloss:-0.38984
# [121]	validation_0-logloss:-0.40486
# [122]	validation_0-logloss:-0.40855
# [123]	validation_0-logloss:-0.40531
# [124]	validation_0-logloss:-0.41235
# [125]	validation_0-logloss:-0.42533
# [126]	validation_0-logloss:-0.42674
# [127]	validation_0-logloss:-0.43099
# [128]	validation_0-logloss:-0.45457
# [129]	validation_0-logloss:-0.44895
# [130]	validation_0-logloss:-0.46192
# [131]	validation_0-logloss:-0.48241
# [132]	validation_0-logloss:-0.48514
# [133]	validation_0-logloss:-0.51003
# [134]	validation_0-logloss:-0.51632
# [135]	validation_0-logloss:-0.52857
# [136]	validation_0-logloss:-0.52604
# [137]	validation_0-logloss:-0.51547
# [138]	validation_0-logloss:-0.51436
# [139]	validation_0-logloss:-0.52133
# [140]	validation_0-logloss:-0.51067
# [141]	validation_0-logloss:-0.50569
# [142]	validation_0-logloss:-0.50773
# [143]	validation_0-logloss:-0.50356
# [144]	validation_0-logloss:-0.50920
# [145]	validation_0-logloss:-0.51843
# [146]	validation_0-logloss:-0.51411
# [147]	validation_0-logloss:-0.52324
# [148]	validation_0-logloss:-0.52442
# [149]	validation_0-logloss:-0.52689
# [150]	validation_0-logloss:-0.52309
# [151]	validation_0-logloss:-0.57158
# [152]	validation_0-logloss:-0.57810
# [153]	validation_0-logloss:-0.56890
# [154]	validation_0-logloss:-0.58092
# [155]	validation_0-logloss:-0.59388
# [156]	validation_0-logloss:-0.58890
# [157]	validation_0-logloss:-0.59740
# [158]	validation_0-logloss:-0.61260
# [159]	validation_0-logloss:-0.59560
# [160]	validation_0-logloss:-0.57521
# [161]	validation_0-logloss:-0.58728
# [162]	validation_0-logloss:-0.58266
# [163]	validation_0-logloss:-0.60462
# [164]	validation_0-logloss:-0.59577
# [165]	validation_0-logloss:-0.60336
# [166]	validation_0-logloss:-0.60961
# [167]	validation_0-logloss:-0.59348
# [168]	validation_0-logloss:-0.58283
# [169]	validation_0-logloss:-0.60190
# [170]	validation_0-logloss:-0.61540
# [171]	validation_0-logloss:-0.61490
# [172]	validation_0-logloss:-0.63364
# [173]	validation_0-logloss:-0.63559
# [174]	validation_0-logloss:-0.64332
# [175]	validation_0-logloss:-0.64278
# [176]	validation_0-logloss:-0.64227
# [177]	validation_0-logloss:-0.64271
# [178]	validation_0-logloss:-0.65249
# [179]	validation_0-logloss:-0.66111
# [180]	validation_0-logloss:-0.68379
# [181]	validation_0-logloss:-0.68781
# [182]	validation_0-logloss:-0.67698
# [183]	validation_0-logloss:-0.70133
# [184]	validation_0-logloss:-0.69144
# [185]	validation_0-logloss:-0.68950
# [186]	validation_0-logloss:-0.68452
# [187]	validation_0-logloss:-0.67745
# [188]	validation_0-logloss:-0.67597
# [189]	validation_0-logloss:-0.67599
# [190]	validation_0-logloss:-0.67624
# [191]	validation_0-logloss:-0.67779
# [192]	validation_0-logloss:-0.69285
# [193]	validation_0-logloss:-0.67972
# [194]	validation_0-logloss:-0.68255
# [195]	validation_0-logloss:-0.67990
# [196]	validation_0-logloss:-0.69518
# [197]	validation_0-logloss:-0.70452
# [198]	validation_0-logloss:-0.70007
# [199]	validation_0-logloss:-0.69505
# [200]	validation_0-logloss:-0.70830
# [201]	validation_0-logloss:-0.69529
# [202]	validation_0-logloss:-0.70326
# [203]	validation_0-logloss:-0.71138
# [204]	validation_0-logloss:-0.70442
# [205]	validation_0-logloss:-0.71177
# [206]	validation_0-logloss:-0.70522
# [207]	validation_0-logloss:-0.70185
# [208]	validation_0-logloss:-0.71031
# [209]	validation_0-logloss:-0.71231
# [210]	validation_0-logloss:-0.73991
# [211]	validation_0-logloss:-0.74175
# [212]	validation_0-logloss:-0.75718
# [213]	validation_0-logloss:-0.74642
# [214]	validation_0-logloss:-0.76507
# [215]	validation_0-logloss:-0.76645
# [216]	validation_0-logloss:-0.77802
# [217]	validation_0-logloss:-0.77243
# [218]	validation_0-logloss:-0.76940
# [219]	validation_0-logloss:-0.77778
# [220]	validation_0-logloss:-0.78331
# [221]	validation_0-logloss:-0.79544
# [222]	validation_0-logloss:-0.79092
# [223]	validation_0-logloss:-0.78064
# [224]	validation_0-logloss:-0.78895
# [225]	validation_0-logloss:-0.79601
# [226]	validation_0-logloss:-0.80054
# [227]	validation_0-logloss:-0.79272
# [228]	validation_0-logloss:-0.79956
# [229]	validation_0-logloss:-0.79256
# [230]	validation_0-logloss:-0.80017
# [231]	validation_0-logloss:-0.79742
# [232]	validation_0-logloss:-0.81443
# [233]	validation_0-logloss:-0.80494
# [234]	validation_0-logloss:-0.79665
# [235]	validation_0-logloss:-0.80723
# [236]	validation_0-logloss:-0.79991
# [237]	validation_0-logloss:-0.81557
# [238]	validation_0-logloss:-0.83279
# [239]	validation_0-logloss:-0.84530
# [240]	validation_0-logloss:-0.85407
# [241]	validation_0-logloss:-0.85647
# [242]	validation_0-logloss:-0.86067
# [243]	validation_0-logloss:-0.87281
# [244]	validation_0-logloss:-0.86910
# [245]	validation_0-logloss:-0.87223
# [246]	validation_0-logloss:-0.85676
# [247]	validation_0-logloss:-0.85249
# [248]	validation_0-logloss:-0.85935
# [249]	validation_0-logloss:-0.86742
# [250]	validation_0-logloss:-0.87056
# [251]	validation_0-logloss:-0.86915
# [252]	validation_0-logloss:-0.88034
# [253]	validation_0-logloss:-0.86640
# [254]	validation_0-logloss:-0.85680
# [255]	validation_0-logloss:-0.85713
# [256]	validation_0-logloss:-0.86492
# [257]	validation_0-logloss:-0.85521
# [258]	validation_0-logloss:-0.86853
# [259]	validation_0-logloss:-0.87223
# [260]	validation_0-logloss:-0.88294
# [261]	validation_0-logloss:-0.87934
# [262]	validation_0-logloss:-0.88151
# [263]	validation_0-logloss:-0.88961
# [264]	validation_0-logloss:-0.89620
# [265]	validation_0-logloss:-0.89332
# [266]	validation_0-logloss:-0.90484
# [267]	validation_0-logloss:-0.89994
# [268]	validation_0-logloss:-0.93425
# [269]	validation_0-logloss:-0.93785
# [270]	validation_0-logloss:-0.95303
# [271]	validation_0-logloss:-0.95831
# [272]	validation_0-logloss:-0.96280
# [273]	validation_0-logloss:-0.95213
# [274]	validation_0-logloss:-0.94958
# [275]	validation_0-logloss:-0.94476
# [276]	validation_0-logloss:-0.94579
# [277]	validation_0-logloss:-0.94209
# [278]	validation_0-logloss:-0.93105
# [279]	validation_0-logloss:-0.92904
# [280]	validation_0-logloss:-0.93660
# [281]	validation_0-logloss:-0.92925
# [282]	validation_0-logloss:-0.92465
# [283]	validation_0-logloss:-0.91372
# [284]	validation_0-logloss:-0.92563
# [285]	validation_0-logloss:-0.92258
# [286]	validation_0-logloss:-0.93764
# [287]	validation_0-logloss:-0.94571
# [288]	validation_0-logloss:-0.95287
# [289]	validation_0-logloss:-0.95416
# [290]	validation_0-logloss:-0.94744
# [291]	validation_0-logloss:-0.96207
# [292]	validation_0-logloss:-0.95207
# [293]	validation_0-logloss:-0.96849
# [294]	validation_0-logloss:-0.96993
# [295]	validation_0-logloss:-0.96943
# [296]	validation_0-logloss:-0.97974
# [297]	validation_0-logloss:-0.98472
# [298]	validation_0-logloss:-0.97794
# [299]	validation_0-logloss:-0.98316

# %%
print(y_b.value_counts(normalize=True))
y_pred_val_b = bst.predict(X_val_b)
print(accuracy_score(y_val_b, y_pred_val_b))

preds_b = bst.predict(X_val_b)
probs = bst.predict_proba(X_test_b)

print(classification_report(y_val_b, preds_b))
# Out:
# Hazard_information_Hazard_score
# 1.0    0.967144
# 0.0    0.032856
# Name: proportion, dtype: float64
# 0.8022440392706872
#               precision    recall  f1-score   support
#
#          0.0       0.10      0.58      0.17        24
#          1.0       0.98      0.81      0.89       689
#
#     accuracy                           0.80       713
#    macro avg       0.54      0.70      0.53       713
# weighted avg       0.95      0.80      0.86       713

# %%
cm = confusion_matrix(y_val_b, preds_b)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %% [markdown]
# ## Regression

# %%
y_r = plast_chem_hazard['Hazard_information_Hazard_score']
print(y_r.value_counts())
X_r = X.copy()
# Out:
# Hazard_information_Hazard_score
# 2.0    2688
# 0.5    1002
# 1.0     902
# 0.0     156
# Name: count, dtype: int64

# %%
# splitting
X_train_r, X_split_r, y_train_r, y_split_r = train_test_split(X_r, y_r, test_size=0.3, stratify=y_r)
X_test_r, X_val_r, y_test_r, y_val_r = train_test_split(X_split_r, y_split_r, test_size=0.5, stratify=y_split_r)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train_b
)

bst = XGBRegressor(tree_method="hist",
                    n_estimators=300,
                    max_depth=4,
                    learning_rate=0.1,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    #eval_metric='mlogloss',
                    #max_delta_step=1,
                    )
# fit model
bst.fit(X_train_r, y_train_r, eval_set=[(X_test_r, y_test_r)])
# make predictions
preds = bst.predict(X_test_r)
# Out:
# [0]	validation_0-rmse:0.68053
# [1]	validation_0-rmse:0.67621
# [2]	validation_0-rmse:0.67252
# [3]	validation_0-rmse:0.66968
# [4]	validation_0-rmse:0.66721
# [5]	validation_0-rmse:0.66402
# [6]	validation_0-rmse:0.66204
# [7]	validation_0-rmse:0.66013
# [8]	validation_0-rmse:0.65842
# [9]	validation_0-rmse:0.65759
# [10]	validation_0-rmse:0.65627
# [11]	validation_0-rmse:0.65424
# [12]	validation_0-rmse:0.65312
# [13]	validation_0-rmse:0.65186
# [14]	validation_0-rmse:0.65196
# [15]	validation_0-rmse:0.65151
# [16]	validation_0-rmse:0.65058
# [17]	validation_0-rmse:0.64995
# [18]	validation_0-rmse:0.64945
# [19]	validation_0-rmse:0.64924
# [20]	validation_0-rmse:0.64858
# [21]	validation_0-rmse:0.64847
# [22]	validation_0-rmse:0.64742
# [23]	validation_0-rmse:0.64732
# [24]	validation_0-rmse:0.64743
# [25]	validation_0-rmse:0.64699
# [26]	validation_0-rmse:0.64720
# [27]	validation_0-rmse:0.64649
# [28]	validation_0-rmse:0.64616
# [29]	validation_0-rmse:0.64589
# [30]	validation_0-rmse:0.64566
# [31]	validation_0-rmse:0.64586
# [32]	validation_0-rmse:0.64531
# [33]	validation_0-rmse:0.64497
# [34]	validation_0-rmse:0.64526
# [35]	validation_0-rmse:0.64510
# [36]	validation_0-rmse:0.64436
# [37]	validation_0-rmse:0.64448
# [38]	validation_0-rmse:0.64445
# [39]	validation_0-rmse:0.64417
# [40]	validation_0-rmse:0.64401
# [41]	validation_0-rmse:0.64403
# [42]	validation_0-rmse:0.64363
# [43]	validation_0-rmse:0.64322
# [44]	validation_0-rmse:0.64343
# [45]	validation_0-rmse:0.64343
# [46]	validation_0-rmse:0.64331
# [47]	validation_0-rmse:0.64348
# [48]	validation_0-rmse:0.64380
# [49]	validation_0-rmse:0.64406
# [50]	validation_0-rmse:0.64414
# [51]	validation_0-rmse:0.64409
# [52]	validation_0-rmse:0.64429
# [53]	validation_0-rmse:0.64414
# [54]	validation_0-rmse:0.64417
# [55]	validation_0-rmse:0.64333
# [56]	validation_0-rmse:0.64306
# [57]	validation_0-rmse:0.64323
# [58]	validation_0-rmse:0.64312
# [59]	validation_0-rmse:0.64297
# [60]	validation_0-rmse:0.64255
# [61]	validation_0-rmse:0.64215
# [62]	validation_0-rmse:0.64147
# [63]	validation_0-rmse:0.64131
# [64]	validation_0-rmse:0.64150
# [65]	validation_0-rmse:0.64145
# [66]	validation_0-rmse:0.64131
# [67]	validation_0-rmse:0.64156
# [68]	validation_0-rmse:0.64153
# [69]	validation_0-rmse:0.64189
# [70]	validation_0-rmse:0.64154
# [71]	validation_0-rmse:0.64114
# [72]	validation_0-rmse:0.64145
# [73]	validation_0-rmse:0.64143
# [74]	validation_0-rmse:0.64136
# [75]	validation_0-rmse:0.64111
# [76]	validation_0-rmse:0.64149
# [77]	validation_0-rmse:0.64163
# [78]	validation_0-rmse:0.64146
# [79]	validation_0-rmse:0.64157
# [80]	validation_0-rmse:0.64168
# [81]	validation_0-rmse:0.64148
# [82]	validation_0-rmse:0.64191
# [83]	validation_0-rmse:0.64204
# [84]	validation_0-rmse:0.64222
# [85]	validation_0-rmse:0.64200
# [86]	validation_0-rmse:0.64187
# [87]	validation_0-rmse:0.64177
# [88]	validation_0-rmse:0.64146
# [89]	validation_0-rmse:0.64136
# [90]	validation_0-rmse:0.64146
# [91]	validation_0-rmse:0.64120
# [92]	validation_0-rmse:0.64123
# [93]	validation_0-rmse:0.64082
# [94]	validation_0-rmse:0.64132
# [95]	validation_0-rmse:0.64083
# [96]	validation_0-rmse:0.64089
# [97]	validation_0-rmse:0.64109
# [98]	validation_0-rmse:0.64136
# [99]	validation_0-rmse:0.64112
# [100]	validation_0-rmse:0.64136
# [101]	validation_0-rmse:0.64141
# [102]	validation_0-rmse:0.64118
# [103]	validation_0-rmse:0.64125
# [104]	validation_0-rmse:0.64143
# [105]	validation_0-rmse:0.64157
# [106]	validation_0-rmse:0.64130
# [107]	validation_0-rmse:0.64149
# [108]	validation_0-rmse:0.64194
# [109]	validation_0-rmse:0.64194
# [110]	validation_0-rmse:0.64202
# [111]	validation_0-rmse:0.64205
# [112]	validation_0-rmse:0.64186
# [113]	validation_0-rmse:0.64194
# [114]	validation_0-rmse:0.64215
# [115]	validation_0-rmse:0.64261
# [116]	validation_0-rmse:0.64244
# [117]	validation_0-rmse:0.64259
# [118]	validation_0-rmse:0.64252
# [119]	validation_0-rmse:0.64265
# [120]	validation_0-rmse:0.64271
# [121]	validation_0-rmse:0.64252
# [122]	validation_0-rmse:0.64214
# [123]	validation_0-rmse:0.64186
# [124]	validation_0-rmse:0.64139
# [125]	validation_0-rmse:0.64135
# [126]	validation_0-rmse:0.64162
# [127]	validation_0-rmse:0.64161
# [128]	validation_0-rmse:0.64149
# [129]	validation_0-rmse:0.64142
# [130]	validation_0-rmse:0.64133
# [131]	validation_0-rmse:0.64140
# [132]	validation_0-rmse:0.64134
# [133]	validation_0-rmse:0.64152
# [134]	validation_0-rmse:0.64161
# [135]	validation_0-rmse:0.64167
# [136]	validation_0-rmse:0.64142
# [137]	validation_0-rmse:0.64160
# [138]	validation_0-rmse:0.64162
# [139]	validation_0-rmse:0.64130
# [140]	validation_0-rmse:0.64111
# [141]	validation_0-rmse:0.64117
# [142]	validation_0-rmse:0.64102
# [143]	validation_0-rmse:0.64074
# [144]	validation_0-rmse:0.64075
# [145]	validation_0-rmse:0.64074
# [146]	validation_0-rmse:0.64071
# [147]	validation_0-rmse:0.64105
# [148]	validation_0-rmse:0.64144
# [149]	validation_0-rmse:0.64142
# [150]	validation_0-rmse:0.64148
# [151]	validation_0-rmse:0.64158
# [152]	validation_0-rmse:0.64188
# [153]	validation_0-rmse:0.64156
# [154]	validation_0-rmse:0.64123
# [155]	validation_0-rmse:0.64131
# [156]	validation_0-rmse:0.64121
# [157]	validation_0-rmse:0.64127
# [158]	validation_0-rmse:0.64110
# [159]	validation_0-rmse:0.64090
# [160]	validation_0-rmse:0.64081
# [161]	validation_0-rmse:0.64081
# [162]	validation_0-rmse:0.64067
# [163]	validation_0-rmse:0.64038
# [164]	validation_0-rmse:0.64020
# [165]	validation_0-rmse:0.64015
# [166]	validation_0-rmse:0.64070
# [167]	validation_0-rmse:0.64053
# [168]	validation_0-rmse:0.64009
# [169]	validation_0-rmse:0.63997
# [170]	validation_0-rmse:0.64010
# [171]	validation_0-rmse:0.63989
# [172]	validation_0-rmse:0.63982
# [173]	validation_0-rmse:0.63973
# [174]	validation_0-rmse:0.63999
# [175]	validation_0-rmse:0.64029
# [176]	validation_0-rmse:0.64038
# [177]	validation_0-rmse:0.64036
# [178]	validation_0-rmse:0.64040
# [179]	validation_0-rmse:0.64066
# [180]	validation_0-rmse:0.64055
# [181]	validation_0-rmse:0.64082
# [182]	validation_0-rmse:0.64039
# [183]	validation_0-rmse:0.64049
# [184]	validation_0-rmse:0.64052
# [185]	validation_0-rmse:0.64048
# [186]	validation_0-rmse:0.64013
# [187]	validation_0-rmse:0.64024
# [188]	validation_0-rmse:0.63997
# [189]	validation_0-rmse:0.64007
# [190]	validation_0-rmse:0.63971
# [191]	validation_0-rmse:0.63951
# [192]	validation_0-rmse:0.63963
# [193]	validation_0-rmse:0.63985
# [194]	validation_0-rmse:0.64006
# [195]	validation_0-rmse:0.64023
# [196]	validation_0-rmse:0.63986
# [197]	validation_0-rmse:0.63995
# [198]	validation_0-rmse:0.63988
# [199]	validation_0-rmse:0.63989
# [200]	validation_0-rmse:0.63944
# [201]	validation_0-rmse:0.63985
# [202]	validation_0-rmse:0.64031
# [203]	validation_0-rmse:0.64039
# [204]	validation_0-rmse:0.64041
# [205]	validation_0-rmse:0.64060
# [206]	validation_0-rmse:0.64050
# [207]	validation_0-rmse:0.64050
# [208]	validation_0-rmse:0.64018
# [209]	validation_0-rmse:0.64023
# [210]	validation_0-rmse:0.64029
# [211]	validation_0-rmse:0.64029
# [212]	validation_0-rmse:0.63982
# [213]	validation_0-rmse:0.63985
# [214]	validation_0-rmse:0.63979
# [215]	validation_0-rmse:0.63994
# [216]	validation_0-rmse:0.63989
# [217]	validation_0-rmse:0.64003
# [218]	validation_0-rmse:0.63980
# [219]	validation_0-rmse:0.64001
# [220]	validation_0-rmse:0.63971
# [221]	validation_0-rmse:0.63998
# [222]	validation_0-rmse:0.63967
# [223]	validation_0-rmse:0.63989
# [224]	validation_0-rmse:0.64004
# [225]	validation_0-rmse:0.64001
# [226]	validation_0-rmse:0.64000
# [227]	validation_0-rmse:0.63985
# [228]	validation_0-rmse:0.64029
# [229]	validation_0-rmse:0.64051
# [230]	validation_0-rmse:0.64068
# [231]	validation_0-rmse:0.64079
# [232]	validation_0-rmse:0.64056
# [233]	validation_0-rmse:0.64062
# [234]	validation_0-rmse:0.64038
# [235]	validation_0-rmse:0.64034
# [236]	validation_0-rmse:0.64037
# [237]	validation_0-rmse:0.64050
# [238]	validation_0-rmse:0.64047
# [239]	validation_0-rmse:0.64067
# [240]	validation_0-rmse:0.64063
# [241]	validation_0-rmse:0.64089
# [242]	validation_0-rmse:0.64112
# [243]	validation_0-rmse:0.64141
# [244]	validation_0-rmse:0.64125
# [245]	validation_0-rmse:0.64133
# [246]	validation_0-rmse:0.64136
# [247]	validation_0-rmse:0.64144
# [248]	validation_0-rmse:0.64114
# [249]	validation_0-rmse:0.64097
# [250]	validation_0-rmse:0.64087
# [251]	validation_0-rmse:0.64107
# [252]	validation_0-rmse:0.64121
# [253]	validation_0-rmse:0.64136
# [254]	validation_0-rmse:0.64131
# [255]	validation_0-rmse:0.64137
# [256]	validation_0-rmse:0.64167
# [257]	validation_0-rmse:0.64157
# [258]	validation_0-rmse:0.64158
# [259]	validation_0-rmse:0.64152
# [260]	validation_0-rmse:0.64167
# [261]	validation_0-rmse:0.64122
# [262]	validation_0-rmse:0.64082
# [263]	validation_0-rmse:0.64129
# [264]	validation_0-rmse:0.64078
# [265]	validation_0-rmse:0.64070
# [266]	validation_0-rmse:0.64089
# [267]	validation_0-rmse:0.64089
# [268]	validation_0-rmse:0.64086
# [269]	validation_0-rmse:0.64058
# [270]	validation_0-rmse:0.64050
# [271]	validation_0-rmse:0.64085
# [272]	validation_0-rmse:0.64101
# [273]	validation_0-rmse:0.64121
# [274]	validation_0-rmse:0.64154
# [275]	validation_0-rmse:0.64195
# [276]	validation_0-rmse:0.64238
# [277]	validation_0-rmse:0.64241
# [278]	validation_0-rmse:0.64295
# [279]	validation_0-rmse:0.64308
# [280]	validation_0-rmse:0.64333
# [281]	validation_0-rmse:0.64359
# [282]	validation_0-rmse:0.64379
# [283]	validation_0-rmse:0.64380
# [284]	validation_0-rmse:0.64378
# [285]	validation_0-rmse:0.64354
# [286]	validation_0-rmse:0.64361
# [287]	validation_0-rmse:0.64350
# [288]	validation_0-rmse:0.64384
# [289]	validation_0-rmse:0.64356
# [290]	validation_0-rmse:0.64416
# [291]	validation_0-rmse:0.64433
# [292]	validation_0-rmse:0.64434
# [293]	validation_0-rmse:0.64412
# [294]	validation_0-rmse:0.64423
# [295]	validation_0-rmse:0.64469
# [296]	validation_0-rmse:0.64457
# [297]	validation_0-rmse:0.64480
# [298]	validation_0-rmse:0.64475
# [299]	validation_0-rmse:0.64506

# %%
y_pred_val_r = bst.predict(X_val_r)
print(f'MAE: {mean_absolute_error(y_val_r, y_pred_val_r)}')

print(f'RMSE: {root_mean_squared_error(y_val_r, y_pred_val_r)}')

corr, p = spearmanr(y_val_r, y_pred_val_r)

print(f'Spearmans Corr: {corr}')
print(y_r.value_counts())

print(r2_score(y_val_r, y_pred_val_r))
# Out:
# MAE: 0.5238542548402998
# RMSE: 0.619044250675097
# Spearmans Corr: 0.4320508715152861
# Hazard_information_Hazard_score
# 2.0    2688
# 0.5    1002
# 1.0     902
# 0.0     156
# Name: count, dtype: int64
# 0.18157498935792693

# %%
# check baseline
dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train_r, y_train_r)

dummy_pred = dummy.predict(X_val_r)

print("Dummy MAE:", mean_absolute_error(y_val_r, dummy_pred))
print("Dummy R2:", r2_score(y_val_r, dummy_pred))
# Out:
# Dummy MAE: 0.6477717670922919
# Dummy R2: -1.032007752588271e-06
