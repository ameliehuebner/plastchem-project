# %%
from xgboost import XGBClassifier, XGBRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.dummy import DummyRegressor
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, r2_score, root_mean_squared_error, mean_absolute_error
from sklearn.utils.class_weight import compute_sample_weight
from utils import load_plastchem, calculate_mfps
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr

# %%
# Data preparation
plast_chem, pcc = load_plastchem(Path.cwd() / "data" / "plastchem_db_v1.0.tsv")

hazard_cols = [
        'Hazard_information_Carcinogenic', 'Hazard_information_Mutagenic', 'Hazard_information_Reproduction', 'Hazard_information_CMR', 'Hazard_information_STOT',
        'Hazard_information_EDC', 'Hazard_information_Aquatic_toxicity', 'Hazard_information_PBT', 'Hazard_information_vPvB', 'Hazard_information_PMT', 'Hazard_information_vPvM'
    ]

# exclude NAs
plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
plast_chem_hazard = plast_chem_hazard.where(plast_chem_hazard['Hazard_information_Toxicity_score'] != 0.25)

# include NAs → test for sparsity algo
#plast_chem_hazard = plast_chem[plast_chem[hazard_cols].notna().any(axis=1)]
#plast_chem_hazard = plast_chem.where(plast_chem['Hazard_information_Toxicity_score'] != 0.25)

print(plast_chem_hazard['Hazard_information_Hazard_score'].value_counts())

# fingerprints
fps = calculate_mfps(plast_chem_hazard, 'Properties_isomeric_smiles')

mask = [fp is not None for fp in fps]
plast_chem_hazard = plast_chem_hazard[mask].copy()
fps = [fp for fp in fps if fp is not None]

X = np.vstack(fps)
# Out:
# Hazard_information_Hazard_score
# 2.0    3049
# 0.5    1188
# 1.0    1041
# 0.0     161
# Name: count, dtype: int64
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] Explicit valence for atom # 1 Cl, 3, is greater than permitted
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors
# [13:00:57] WARNING: not removing hydrogen atom without neighbors

# %% [markdown]
# ## multiclass classification
# → balance with class size? undersample neg? \
# → TODO: hyperparameter optimization

# %%
# data prep for multiclass
# 1, 2 hazardous; 0.5 less hazardous; 0.25 under development → exclude; 0 not hazardous
y = plast_chem_hazard['Hazard_information_Hazard_score'].replace(2, 3).replace(1, 2).replace(0.5, 1)
# afterwards: 2, 3 hazardous; 1 less hazardous; 0.5 non hazardous

# %%
# splitting
X_train, X_split, y_train, y_split = train_test_split(X, y, test_size=0.3, stratify=y)
X_test, X_val, y_test, y_val = train_test_split(X_split, y_split, test_size=0.5, stratify=y_split)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train
)

bst = XGBClassifier(tree_method="hist",
                    n_estimators=300,
                    max_depth=12,
                    learning_rate=0.05,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    eval_metric='mlogloss',
                    max_delta_step=1,
                    booster='gbtree'
                    # set to neg_class_size/pos_class_size
                    #scale_pos_weight=0.56
                    )
# fit model
bst.fit(X_train, y_train, eval_set=[(X_test, y_test)])
# make predictions
preds = bst.predict(X_test)
# Out:
# [0]	validation_0-mlogloss:1.07349
# [1]	validation_0-mlogloss:1.06705
# [2]	validation_0-mlogloss:1.05968
# [3]	validation_0-mlogloss:1.05359
# [4]	validation_0-mlogloss:1.04874
# [5]	validation_0-mlogloss:1.04287
# [6]	validation_0-mlogloss:1.03845
# [7]	validation_0-mlogloss:1.03384
# [8]	validation_0-mlogloss:1.02920
# [9]	validation_0-mlogloss:1.02473
# [10]	validation_0-mlogloss:1.02073
# [11]	validation_0-mlogloss:1.01639
# [12]	validation_0-mlogloss:1.01308
# [13]	validation_0-mlogloss:1.00950
# [14]	validation_0-mlogloss:1.00686
# [15]	validation_0-mlogloss:1.00366
# [16]	validation_0-mlogloss:1.00077
# [17]	validation_0-mlogloss:0.99793
# [18]	validation_0-mlogloss:0.99556
# [19]	validation_0-mlogloss:0.99358
# [20]	validation_0-mlogloss:0.99200
# [21]	validation_0-mlogloss:0.99025
# [22]	validation_0-mlogloss:0.98871
# [23]	validation_0-mlogloss:0.98682
# [24]	validation_0-mlogloss:0.98547
# [25]	validation_0-mlogloss:0.98286
# [26]	validation_0-mlogloss:0.98199
# [27]	validation_0-mlogloss:0.98019
# [28]	validation_0-mlogloss:0.97905
# [29]	validation_0-mlogloss:0.97715
# [30]	validation_0-mlogloss:0.97604
# [31]	validation_0-mlogloss:0.97534
# [32]	validation_0-mlogloss:0.97491
# [33]	validation_0-mlogloss:0.97300
# [34]	validation_0-mlogloss:0.97250
# [35]	validation_0-mlogloss:0.97100
# [36]	validation_0-mlogloss:0.96956
# [37]	validation_0-mlogloss:0.96818
# [38]	validation_0-mlogloss:0.96778
# [39]	validation_0-mlogloss:0.96690
# [40]	validation_0-mlogloss:0.96605
# [41]	validation_0-mlogloss:0.96525
# [42]	validation_0-mlogloss:0.96428
# [43]	validation_0-mlogloss:0.96404
# [44]	validation_0-mlogloss:0.96312
# [45]	validation_0-mlogloss:0.96288
# [46]	validation_0-mlogloss:0.96223
# [47]	validation_0-mlogloss:0.96200
# [48]	validation_0-mlogloss:0.96110
# [49]	validation_0-mlogloss:0.96028
# [50]	validation_0-mlogloss:0.96014
# [51]	validation_0-mlogloss:0.95986
# [52]	validation_0-mlogloss:0.95911
# [53]	validation_0-mlogloss:0.95877
# [54]	validation_0-mlogloss:0.95868
# [55]	validation_0-mlogloss:0.95815
# [56]	validation_0-mlogloss:0.95758
# [57]	validation_0-mlogloss:0.95733
# [58]	validation_0-mlogloss:0.95624
# [59]	validation_0-mlogloss:0.95592
# [60]	validation_0-mlogloss:0.95572
# [61]	validation_0-mlogloss:0.95581
# [62]	validation_0-mlogloss:0.95597
# [63]	validation_0-mlogloss:0.95561
# [64]	validation_0-mlogloss:0.95506
# [65]	validation_0-mlogloss:0.95406
# [66]	validation_0-mlogloss:0.95412
# [67]	validation_0-mlogloss:0.95364
# [68]	validation_0-mlogloss:0.95349
# [69]	validation_0-mlogloss:0.95343
# [70]	validation_0-mlogloss:0.95326
# [71]	validation_0-mlogloss:0.95319
# [72]	validation_0-mlogloss:0.95325
# [73]	validation_0-mlogloss:0.95323
# [74]	validation_0-mlogloss:0.95337
# [75]	validation_0-mlogloss:0.95348
# [76]	validation_0-mlogloss:0.95375
# [77]	validation_0-mlogloss:0.95350
# [78]	validation_0-mlogloss:0.95341
# [79]	validation_0-mlogloss:0.95306
# [80]	validation_0-mlogloss:0.95326
# [81]	validation_0-mlogloss:0.95331
# [82]	validation_0-mlogloss:0.95326
# [83]	validation_0-mlogloss:0.95336
# [84]	validation_0-mlogloss:0.95341
# [85]	validation_0-mlogloss:0.95354
# [86]	validation_0-mlogloss:0.95346
# [87]	validation_0-mlogloss:0.95377
# [88]	validation_0-mlogloss:0.95362
# [89]	validation_0-mlogloss:0.95340
# [90]	validation_0-mlogloss:0.95322
# [91]	validation_0-mlogloss:0.95341
# [92]	validation_0-mlogloss:0.95343
# [93]	validation_0-mlogloss:0.95328
# [94]	validation_0-mlogloss:0.95335
# [95]	validation_0-mlogloss:0.95310
# [96]	validation_0-mlogloss:0.95281
# [97]	validation_0-mlogloss:0.95243
# [98]	validation_0-mlogloss:0.95271
# [99]	validation_0-mlogloss:0.95284
# [100]	validation_0-mlogloss:0.95272
# [101]	validation_0-mlogloss:0.95299
# [102]	validation_0-mlogloss:0.95264
# [103]	validation_0-mlogloss:0.95279
# [104]	validation_0-mlogloss:0.95273
# [105]	validation_0-mlogloss:0.95272
# [106]	validation_0-mlogloss:0.95290
# [107]	validation_0-mlogloss:0.95294
# [108]	validation_0-mlogloss:0.95294
# [109]	validation_0-mlogloss:0.95262
# [110]	validation_0-mlogloss:0.95305
# [111]	validation_0-mlogloss:0.95340
# [112]	validation_0-mlogloss:0.95336
# [113]	validation_0-mlogloss:0.95368
# [114]	validation_0-mlogloss:0.95381
# [115]	validation_0-mlogloss:0.95385
# [116]	validation_0-mlogloss:0.95376
# [117]	validation_0-mlogloss:0.95393
# [118]	validation_0-mlogloss:0.95378
# [119]	validation_0-mlogloss:0.95417
# [120]	validation_0-mlogloss:0.95454
# [121]	validation_0-mlogloss:0.95457
# [122]	validation_0-mlogloss:0.95503
# [123]	validation_0-mlogloss:0.95493
# [124]	validation_0-mlogloss:0.95509
# [125]	validation_0-mlogloss:0.95573
# [126]	validation_0-mlogloss:0.95590
# [127]	validation_0-mlogloss:0.95604
# [128]	validation_0-mlogloss:0.95599
# [129]	validation_0-mlogloss:0.95578
# [130]	validation_0-mlogloss:0.95619
# [131]	validation_0-mlogloss:0.95644
# [132]	validation_0-mlogloss:0.95634
# [133]	validation_0-mlogloss:0.95651
# [134]	validation_0-mlogloss:0.95630
# [135]	validation_0-mlogloss:0.95640
# [136]	validation_0-mlogloss:0.95666
# [137]	validation_0-mlogloss:0.95690
# [138]	validation_0-mlogloss:0.95643
# [139]	validation_0-mlogloss:0.95637
# [140]	validation_0-mlogloss:0.95623
# [141]	validation_0-mlogloss:0.95626
# [142]	validation_0-mlogloss:0.95631
# [143]	validation_0-mlogloss:0.95635
# [144]	validation_0-mlogloss:0.95619
# [145]	validation_0-mlogloss:0.95655
# [146]	validation_0-mlogloss:0.95661
# [147]	validation_0-mlogloss:0.95631
# [148]	validation_0-mlogloss:0.95661
# [149]	validation_0-mlogloss:0.95654
# [150]	validation_0-mlogloss:0.95664
# [151]	validation_0-mlogloss:0.95680
# [152]	validation_0-mlogloss:0.95692
# [153]	validation_0-mlogloss:0.95657
# [154]	validation_0-mlogloss:0.95688
# [155]	validation_0-mlogloss:0.95681
# [156]	validation_0-mlogloss:0.95682
# [157]	validation_0-mlogloss:0.95690
# [158]	validation_0-mlogloss:0.95703
# [159]	validation_0-mlogloss:0.95667
# [160]	validation_0-mlogloss:0.95669
# [161]	validation_0-mlogloss:0.95674
# [162]	validation_0-mlogloss:0.95673
# [163]	validation_0-mlogloss:0.95716
# [164]	validation_0-mlogloss:0.95694
# [165]	validation_0-mlogloss:0.95685
# [166]	validation_0-mlogloss:0.95727
# [167]	validation_0-mlogloss:0.95726
# [168]	validation_0-mlogloss:0.95784
# [169]	validation_0-mlogloss:0.95856
# [170]	validation_0-mlogloss:0.95840
# [171]	validation_0-mlogloss:0.95838
# [172]	validation_0-mlogloss:0.95862
# [173]	validation_0-mlogloss:0.95853
# [174]	validation_0-mlogloss:0.95831
# [175]	validation_0-mlogloss:0.95820
# [176]	validation_0-mlogloss:0.95808
# [177]	validation_0-mlogloss:0.95816
# [178]	validation_0-mlogloss:0.95808
# [179]	validation_0-mlogloss:0.95813
# [180]	validation_0-mlogloss:0.95806
# [181]	validation_0-mlogloss:0.95850
# [182]	validation_0-mlogloss:0.95871
# [183]	validation_0-mlogloss:0.95878
# [184]	validation_0-mlogloss:0.95874
# [185]	validation_0-mlogloss:0.95916
# [186]	validation_0-mlogloss:0.95912
# [187]	validation_0-mlogloss:0.95944
# [188]	validation_0-mlogloss:0.95980
# [189]	validation_0-mlogloss:0.95980
# [190]	validation_0-mlogloss:0.95991
# [191]	validation_0-mlogloss:0.96007
# [192]	validation_0-mlogloss:0.96005
# [193]	validation_0-mlogloss:0.96026
# [194]	validation_0-mlogloss:0.96015
# [195]	validation_0-mlogloss:0.96012
# [196]	validation_0-mlogloss:0.96043
# [197]	validation_0-mlogloss:0.96059
# [198]	validation_0-mlogloss:0.96078
# [199]	validation_0-mlogloss:0.96080
# [200]	validation_0-mlogloss:0.96095
# [201]	validation_0-mlogloss:0.96117
# [202]	validation_0-mlogloss:0.96133
# [203]	validation_0-mlogloss:0.96165
# [204]	validation_0-mlogloss:0.96206
# [205]	validation_0-mlogloss:0.96173
# [206]	validation_0-mlogloss:0.96169
# [207]	validation_0-mlogloss:0.96207
# [208]	validation_0-mlogloss:0.96224
# [209]	validation_0-mlogloss:0.96219
# [210]	validation_0-mlogloss:0.96206
# [211]	validation_0-mlogloss:0.96256
# [212]	validation_0-mlogloss:0.96239
# [213]	validation_0-mlogloss:0.96238
# [214]	validation_0-mlogloss:0.96229
# [215]	validation_0-mlogloss:0.96252
# [216]	validation_0-mlogloss:0.96240
# [217]	validation_0-mlogloss:0.96267
# [218]	validation_0-mlogloss:0.96294
# [219]	validation_0-mlogloss:0.96295
# [220]	validation_0-mlogloss:0.96314
# [221]	validation_0-mlogloss:0.96333
# [222]	validation_0-mlogloss:0.96342
# [223]	validation_0-mlogloss:0.96336
# [224]	validation_0-mlogloss:0.96337
# [225]	validation_0-mlogloss:0.96337
# [226]	validation_0-mlogloss:0.96328
# [227]	validation_0-mlogloss:0.96369
# [228]	validation_0-mlogloss:0.96370
# [229]	validation_0-mlogloss:0.96372
# [230]	validation_0-mlogloss:0.96386
# [231]	validation_0-mlogloss:0.96369
# [232]	validation_0-mlogloss:0.96375
# [233]	validation_0-mlogloss:0.96366
# [234]	validation_0-mlogloss:0.96355
# [235]	validation_0-mlogloss:0.96353
# [236]	validation_0-mlogloss:0.96400
# [237]	validation_0-mlogloss:0.96421
# [238]	validation_0-mlogloss:0.96446
# [239]	validation_0-mlogloss:0.96488
# [240]	validation_0-mlogloss:0.96487
# [241]	validation_0-mlogloss:0.96528
# [242]	validation_0-mlogloss:0.96514
# [243]	validation_0-mlogloss:0.96508
# [244]	validation_0-mlogloss:0.96552
# [245]	validation_0-mlogloss:0.96532
# [246]	validation_0-mlogloss:0.96522
# [247]	validation_0-mlogloss:0.96500
# [248]	validation_0-mlogloss:0.96495
# [249]	validation_0-mlogloss:0.96503
# [250]	validation_0-mlogloss:0.96494
# [251]	validation_0-mlogloss:0.96505
# [252]	validation_0-mlogloss:0.96543
# [253]	validation_0-mlogloss:0.96544
# [254]	validation_0-mlogloss:0.96603
# [255]	validation_0-mlogloss:0.96595
# [256]	validation_0-mlogloss:0.96622
# [257]	validation_0-mlogloss:0.96625
# [258]	validation_0-mlogloss:0.96628
# [259]	validation_0-mlogloss:0.96640
# [260]	validation_0-mlogloss:0.96639
# [261]	validation_0-mlogloss:0.96651
# [262]	validation_0-mlogloss:0.96721
# [263]	validation_0-mlogloss:0.96736
# [264]	validation_0-mlogloss:0.96710
# [265]	validation_0-mlogloss:0.96742
# [266]	validation_0-mlogloss:0.96735
# [267]	validation_0-mlogloss:0.96764
# [268]	validation_0-mlogloss:0.96793
# [269]	validation_0-mlogloss:0.96823
# [270]	validation_0-mlogloss:0.96849
# [271]	validation_0-mlogloss:0.96848
# [272]	validation_0-mlogloss:0.96832
# [273]	validation_0-mlogloss:0.96850
# [274]	validation_0-mlogloss:0.96873
# [275]	validation_0-mlogloss:0.96900
# [276]	validation_0-mlogloss:0.96898
# [277]	validation_0-mlogloss:0.96935
# [278]	validation_0-mlogloss:0.96972
# [279]	validation_0-mlogloss:0.96998
# [280]	validation_0-mlogloss:0.97030
# [281]	validation_0-mlogloss:0.97033
# [282]	validation_0-mlogloss:0.97035
# [283]	validation_0-mlogloss:0.97050
# [284]	validation_0-mlogloss:0.97082
# [285]	validation_0-mlogloss:0.97067
# [286]	validation_0-mlogloss:0.97033
# [287]	validation_0-mlogloss:0.97024
# [288]	validation_0-mlogloss:0.97009
# [289]	validation_0-mlogloss:0.97034
# [290]	validation_0-mlogloss:0.97052
# [291]	validation_0-mlogloss:0.97082
# [292]	validation_0-mlogloss:0.97131
# [293]	validation_0-mlogloss:0.97118
# [294]	validation_0-mlogloss:0.97151
# [295]	validation_0-mlogloss:0.97157
# [296]	validation_0-mlogloss:0.97163
# [297]	validation_0-mlogloss:0.97175
# [298]	validation_0-mlogloss:0.97203
# [299]	validation_0-mlogloss:0.97220

# %%
print(y.value_counts(normalize=True))
y_pred_val = bst.predict(X_val)
print(accuracy_score(y_val, y_pred_val))
preds = bst.predict(X_val)
probs = bst.predict_proba(X_test)

print(classification_report(y_val, preds))
print("ROC-AUC:", roc_auc_score(y_test, probs, multi_class='ovo'))
# Out:
# Hazard_information_Hazard_score
# 3.0    0.566133
# 1.0    0.211036
# 2.0    0.189975
# 0.0    0.032856
# Name: proportion, dtype: float64
# 0.6115007012622721
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.09      0.15        23
#          1.0       0.52      0.34      0.41       151
#          2.0       0.48      0.30      0.37       135
#          3.0       0.65      0.85      0.74       404
#
#     accuracy                           0.61       713
#    macro avg       0.54      0.39      0.42       713
# weighted avg       0.59      0.61      0.58       713
#
# ROC-AUC: 0.7061377145687181

# %%
cm = confusion_matrix(y_val, preds)
disp = ConfusionMatrixDisplay(cm)#, display_labels=class_names)
disp.plot()#xticks_rotation='vertical')
plt.show()

# %% [markdown]
# ### with gridsearchcv
# - Zielpipeline: PCA mit GridSearch um Anzahl der Komponenten festzulegen, GridSearch Parameter XGBoost, Prediction

# %%
# %%time 

param_grid = {
    'max_depth': [3, 4, 5],
    'learning_rate' : [0.2, 0.1, 0.01],
    'n_estimators' : [400, 500, 600]
}

model = XGBClassifier(
    tree_method = 'hist'
)

grid_search = GridSearchCV(estimator=model,
                           param_grid=param_grid,
                           cv=5, 
                           n_jobs=-1,
                           verbose=10)

grid_search.fit(X_train, y_train)

# Print best score and parameters
print(f"Best score: {grid_search.best_score_:.3f}")
print(f"Best parameters: {grid_search.best_params_}")

# Access best model
best_model = grid_search.best_estimator_

# # Save best model
# best_model.save_model('best_model.ubj')

# # Load saved model
# loaded_model = XGBClassifier()
# loaded_model.load_model('best_model.ubj')

# Use loaded model for predictions
predictions = best_model.predict(X_test)

# Print accuracy score
accuracy = best_model.score(X_test, y_test)
print(f"Accuracy: {accuracy:.3f}")
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 5/5; 3/27] START learning_rate=0.2, max_depth=3, n_estimators=600...........
# [CV 5/5; 3/27] END learning_rate=0.2, max_depth=3, n_estimators=600;, score=0.583 total time= 5.0min
# [CV 1/5; 7/27] START learning_rate=0.2, max_depth=5, n_estimators=400...........
# [CV 1/5; 7/27] END learning_rate=0.2, max_depth=5, n_estimators=400;, score=0.585 total time= 5.5min
# [CV 2/5; 9/27] START learning_rate=0.2, max_depth=5, n_estimators=600...........
# [CV 2/5; 9/27] END learning_rate=0.2, max_depth=5, n_estimators=600;, score=0.609 total time= 8.3min
# [CV 4/5; 13/27] START learning_rate=0.1, max_depth=4, n_estimators=400..........
# [CV 4/5; 13/27] END learning_rate=0.1, max_depth=4, n_estimators=400;, score=0.605 total time= 4.4min
# [CV 5/5; 16/27] START learning_rate=0.1, max_depth=5, n_estimators=400..........
# [CV 5/5; 16/27] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.592 total time= 5.5min
# [CV 1/5; 20/27] START learning_rate=0.01, max_depth=3, n_estimators=500.........
# [CV 1/5; 20/27] END learning_rate=0.01, max_depth=3, n_estimators=500;, score=0.592 total time= 4.2min
# [CV 2/5; 22/27] START learning_rate=0.01, max_depth=4, n_estimators=400.........
# [CV 2/5; 22/27] END learning_rate=0.01, max_depth=4, n_estimators=400;, score=0.605 total time= 4.4min
# [CV 3/5; 25/27] START learning_rate=0.01, max_depth=5, n_estimators=400.........
# [CV 3/5; 25/27] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.592 total time= 5.6min
# [CV 4/5; 2/27] START learning_rate=0.2, max_depth=3, n_estimators=500...........
# [CV 4/5; 2/27] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.598 total time= 4.2min
# [CV 5/5; 5/27] START learning_rate=0.2, max_depth=4, n_estimators=500...........
# [CV 5/5; 5/27] END learning_rate=0.2, max_depth=4, n_estimators=500;, score=0.575 total time= 5.5min
# [CV 1/5; 9/27] START learning_rate=0.2, max_depth=5, n_estimators=600...........
# [CV 1/5; 9/27] END learning_rate=0.2, max_depth=5, n_estimators=600;, score=0.588 total time= 8.3min
# [CV 3/5; 13/27] START learning_rate=0.1, max_depth=4, n_estimators=400..........
# [CV 3/5; 13/27] END learning_rate=0.1, max_depth=4, n_estimators=400;, score=0.598 total time= 4.4min
# [CV 4/5; 16/27] START learning_rate=0.1, max_depth=5, n_estimators=400..........
# [CV 4/5; 16/27] END learning_rate=0.1, max_depth=5, n_estimators=400;, score=0.599 total time= 5.6min
# [CV 3/5; 19/27] START learning_rate=0.01, max_depth=3, n_estimators=400.........
# [CV 3/5; 19/27] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.592 total time= 3.3min
# [CV 1/5; 21/27] START learning_rate=0.01, max_depth=3, n_estimators=600.........
# [CV 1/5; 21/27] END learning_rate=0.01, max_depth=3, n_estimators=600;, score=0.594 total time= 5.0min
# [CV 3/5; 24/27] START learning_rate=0.01, max_depth=4, n_estimators=600.........
# [CV 3/5; 24/27] END learning_rate=0.01, max_depth=4, n_estimators=600;, score=0.598 total time= 6.7min
# [CV 1/5; 2/27] START learning_rate=0.2, max_depth=3, n_estimators=500...........
# [CV 1/5; 2/27] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.582 total time= 4.2min
# [CV 2/5; 5/27] START learning_rate=0.2, max_depth=4, n_estimators=500...........
# [CV 2/5; 5/27] END learning_rate=0.2, max_depth=4, n_estimators=500;, score=0.606 total time= 5.5min
# [CV 3/5; 8/27] START learning_rate=0.2, max_depth=5, n_estimators=500...........
# [CV 3/5; 8/27] END learning_rate=0.2, max_depth=5, n_estimators=500;, score=0.580 total time= 6.9min
# [CV 2/5; 12/27] START learning_rate=0.1, max_depth=3, n_estimators=600..........
# [CV 2/5; 12/27] END learning_rate=0.1, max_depth=3, n_estimators=600;, score=0.621 total time= 5.0min
# [CV 4/5; 15/27] START learning_rate=0.1, max_depth=4, n_estimators=600..........
# [CV 4/5; 15/27] END learning_rate=0.1, max_depth=4, n_estimators=600;, score=0.599 total time= 6.6min
# [CV 4/5; 19/27] START learning_rate=0.01, max_depth=3, n_estimators=400.........
# [CV 4/5; 19/27] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.598 total time= 3.3min
# [CV 2/5; 21/27] START learning_rate=0.01, max_depth=3, n_estimators=600.........
# [CV 2/5; 21/27] END learning_rate=0.01, max_depth=3, n_estimators=600;, score=0.611 total time= 5.0min
# [CV 4/5; 24/27] START learning_rate=0.01, max_depth=4, n_estimators=600.........
# [CV 4/5; 24/27] END learning_rate=0.01, max_depth=4, n_estimators=600;, score=0.608 total time= 6.7min
# [CV 4/5; 1/27] START learning_rate=0.2, max_depth=3, n_estimators=400...........
# [CV 4/5; 1/27] END learning_rate=0.2, max_depth=3, n_estimators=400;, score=0.601 total time= 3.3min
# [CV 2/5; 4/27] START learning_rate=0.2, max_depth=4, n_estimators=400...........
# [CV 2/5; 4/27] END learning_rate=0.2, max_depth=4, n_estimators=400;, score=0.608 total time= 4.4min
# [CV 3/5; 7/27] START learning_rate=0.2, max_depth=5, n_estimators=400...........
# [CV 3/5; 7/27] END learning_rate=0.2, max_depth=5, n_estimators=400;, score=0.576 total time= 5.5min
# [CV 4/5; 10/27] START learning_rate=0.1, max_depth=3, n_estimators=400..........
# [CV 4/5; 10/27] END learning_rate=0.1, max_depth=3, n_estimators=400;, score=0.607 total time= 3.3min
# [CV 3/5; 12/27] START learning_rate=0.1, max_depth=3, n_estimators=600..........
# [CV 3/5; 12/27] END learning_rate=0.1, max_depth=3, n_estimators=600;, score=0.605 total time= 5.0min
# [CV 5/5; 15/27] START learning_rate=0.1, max_depth=4, n_estimators=600..........
# [CV 5/5; 15/27] END learning_rate=0.1, max_depth=4, n_estimators=600;, score=0.590 total time= 6.6min
# [CV 5/5; 19/27] START learning_rate=0.01, max_depth=3, n_estimators=400.........
# [CV 5/5; 19/27] END learning_rate=0.01, max_depth=3, n_estimators=400;, score=0.593 total time= 3.3min
# [CV 3/5; 21/27] START learning_rate=0.01, max_depth=3, n_estimators=600.........
# [CV 3/5; 21/27] END learning_rate=0.01, max_depth=3, n_estimators=600;, score=0.594 total time= 5.0min
# [CV 5/5; 24/27] START learning_rate=0.01, max_depth=4, n_estimators=600.........
# [CV 5/5; 24/27] END learning_rate=0.01, max_depth=4, n_estimators=600;, score=0.608 total time= 6.7min
# [CV 3/5; 2/27] START learning_rate=0.2, max_depth=3, n_estimators=500...........
# [CV 3/5; 2/27] END learning_rate=0.2, max_depth=3, n_estimators=500;, score=0.595 total time= 4.2min
# [CV 1/5; 6/27] START learning_rate=0.2, max_depth=4, n_estimators=600...........
# [CV 1/5; 6/27] END learning_rate=0.2, max_depth=4, n_estimators=600;, score=0.579 total time= 6.7min
# [CV 4/5; 9/27] START learning_rate=0.2, max_depth=5, n_estimators=600...........
# [CV 4/5; 9/27] END learning_rate=0.2, max_depth=5, n_estimators=600;, score=0.583 total time= 8.4min
# [CV 5/5; 14/27] START learning_rate=0.1, max_depth=4, n_estimators=500..........
# [CV 5/5; 14/27] END learning_rate=0.1, max_depth=4, n_estimators=500;, score=0.589 total time= 5.6min
# [CV 1/5; 18/27] START learning_rate=0.1, max_depth=5, n_estimators=600..........
# [CV 1/5; 18/27] END learning_rate=0.1, max_depth=5, n_estimators=600;, score=0.588 total time= 8.4min
# [CV 3/5; 22/27] START learning_rate=0.01, max_depth=4, n_estimators=400.........
# [CV 3/5; 22/27] END learning_rate=0.01, max_depth=4, n_estimators=400;, score=0.592 total time= 4.5min
# [CV 4/5; 25/27] START learning_rate=0.01, max_depth=5, n_estimators=400.........
# [CV 4/5; 25/27] END learning_rate=0.01, max_depth=5, n_estimators=400;, score=0.601 total time= 5.6min
# Best score: 0.605
# Best parameters: {'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 500}
# Accuracy: 0.590
# CPU times: user 9min 1s, sys: 1.49 s, total: 9min 2s
# Wall time: 49min 14s

# %% [markdown]
# ## binary classification

# %%
# less hazardous and hazardous 1 and 2 get same category
y_b = plast_chem_hazard['Hazard_information_Hazard_score'].replace(0.5,1).replace(2,1).replace(3,1)
X_b = X.copy()
print(y_b.value_counts(normalize=True))

# %%
# splitting
X_train_b, X_split_b, y_train_b, y_split_b = train_test_split(X_b, y_b, test_size=0.3, stratify=y_b)
X_test_b, X_val_b, y_test_b, y_val_b = train_test_split(X_split_b, y_split_b, test_size=0.5, stratify=y_split_b)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train_b
)

bst = XGBClassifier(tree_method="hist",
                    n_estimators=300,
                    max_depth=4,
                    learning_rate=0.1,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    #eval_metric='mlogloss',
                    #max_delta_step=1,
                    # set to neg_class_size/pos_class_size
                    scale_pos_weight=0.032856/0.967144
                    )
# fit model
bst.fit(X_train_b, y_train_b, eval_set=[(X_test, y_test)])
# make predictions
preds = bst.predict(X_val_b)

# %%
print(y_b.value_counts(normalize=True))
y_pred_val_b = bst.predict(X_val_b)
print(accuracy_score(y_val_b, y_pred_val_b))

preds_b = bst.predict(X_val_b)
probs = bst.predict_proba(X_test_b)

print(classification_report(y_val_b, preds_b))

# %%
cm = confusion_matrix(y_val_b, preds_b)
disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()

# %% [markdown]
# ## Regression

# %%
y_r = plast_chem_hazard['Hazard_information_Hazard_score']
print(y_r.value_counts())
X_r = X.copy()

# %%
# splitting
X_train_r, X_split_r, y_train_r, y_split_r = train_test_split(X_r, y_r, test_size=0.3, stratify=y_r)
X_test_r, X_val_r, y_test_r, y_val_r = train_test_split(X_split_r, y_split_r, test_size=0.5, stratify=y_split_r)

# %%
# create model instance
# try this but idk if it can handle multiclass
sample_weights = compute_sample_weight(
    class_weight="balanced",
    y=y_train_b
)

bst = XGBRegressor(tree_method="hist",
                    n_estimators=300,
                    max_depth=4,
                    learning_rate=0.1,
                    subsample=0.8,
                    colsample_bytree=0.8,
                    #eval_metric='mlogloss',
                    #max_delta_step=1,
                    )
# fit model
bst.fit(X_train_r, y_train_r, eval_set=[(X_test_r, y_test_r)])
# make predictions
preds = bst.predict(X_test_r)

# %%
y_pred_val_r = bst.predict(X_val_r)
print(f'MAE: {mean_absolute_error(y_val_r, y_pred_val_r)}')

print(f'RMSE: {root_mean_squared_error(y_val_r, y_pred_val_r)}')

corr, p = spearmanr(y_val_r, y_pred_val_r)

print(f'Spearmans Corr: {corr}')
print(y_r.value_counts())

print(r2_score(y_val_r, y_pred_val_r))

# %%
# check baseline
dummy = DummyRegressor(strategy="mean")
dummy.fit(X_train_r, y_train_r)

dummy_pred = dummy.predict(X_val_r)

print("Dummy MAE:", mean_absolute_error(y_val_r, dummy_pred))
print("Dummy R2:", r2_score(y_val_r, dummy_pred))
